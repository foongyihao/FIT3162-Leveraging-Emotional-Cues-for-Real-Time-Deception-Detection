# %%
# !pip install alive_progress
# Out:
# Collecting alive_progress
#   Downloading alive_progress-3.2.0-py3-none-any.whl.metadata (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.6/70.6 kB 5.8 MB/s eta 0:00:00
# Collecting about-time==4.2.1 (from alive_progress)
#   Downloading about_time-4.2.1-py3-none-any.whl.metadata (13 kB)
# Collecting grapheme==0.6.0 (from alive_progress)
#   Downloading grapheme-0.6.0.tar.gz (207 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 15.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Downloading alive_progress-3.2.0-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 3.5 MB/s eta 0:00:00
# Downloading about_time-4.2.1-py3-none-any.whl (13 kB)
# Building wheels for collected packages: grapheme
#   Building wheel for grapheme (setup.py) ... done
#   Created wheel for grapheme: filename=grapheme-0.6.0-py3-none-any.whl size=210082 sha256=4a4995def64901fc43c8a58b63792bce1f325f411474ca138fc1db1b22f0ea67
#   Stored in directory: /root/.cache/pip/wheels/ee/3b/0b/1b865800e916d671a24028d884698674138632a83fdfad4926
# Successfully built grapheme
# Installing collected packages: grapheme, about-time, alive_progress
# Successfully installed about-time-4.2.1 alive_progress-3.2.0 grapheme-0.6.0

# %% [markdown]
# # Import Essential Libraries

# %%
import sys, os
import pandas as pd
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
from sklearn.model_selection import train_test_split
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras.losses import categorical_crossentropy
from keras.optimizers import Adam
from keras.regularizers import l2
from keras.callbacks import ReduceLROnPlateau, TensorBoard, EarlyStopping, ModelCheckpoint
from keras.models import load_model
from keras.models import model_from_json
import tensorflow as tf
from tensorflow.python.framework import type_spec

# %% [markdown]
# # Mount Google Drive

# %% [markdown]
# First let's mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# Make sure that we are using a GPU for tensorflow

# %%
import tensorflow as tf

# detect whether or not GPU is available
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# # Part 1: Facial Expression Recognition

# %% [markdown]
# ## Preprocessing
# Using the built FER2013 model
# Reference:
# 1. Facial Emotion Recognition on FER2013 Dataset Using a Convolutional Neural Network
# https://github.com/gitshanks/fer2013
# 2. Kaggle challenge (FER-2013): https://www.kaggle.com/c/challenges-in-representation-learning-facial-expression-recognition-challenge/data

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

pathname = '/content/drive/MyDrive/FIT3162/deep-lie/fer2013/'
data = pd.read_csv(pathname+'fer2013.csv')

width, height = 48, 48

# %%
datapoints = data['pixels'].tolist()

# getting features for training
X = []
for xseq in datapoints:
    xx = [int(xp) for xp in xseq.split(' ')]
    xx = np.asarray(xx).reshape(width, height)
    X.append(xx.astype('float32'))

X = np.asarray(X)
X = np.expand_dims(X, -1)

# getting labels for training
y = pd.get_dummies(data['emotion']).values

print(f"X.shape={X.shape}, y.shape={y.shape}")
# storing them using numpy
np.save(pathname+'fdataX', X)
np.save(pathname+'flabels', y)

print("Preprocessing Done")
print("Number of Features: "+str(len(X[0])))
print("Number of Labels: " + str(len(y[0])))
print("Number of examples in dataset:"+str(len(X)))
print("X,y stored in fdataX.npy and flabels.npy respectively")
# Out:
# X.shape=(35887, 48, 48, 1), y.shape=(35887, 7)
# Preprocessing Done
# Number of Features: 48
# Number of Labels: 7
# Number of examples in dataset:35887
# X,y stored in fdataX.npy and flabels.npy respectively

# %%
import cv2
from google.colab.patches import cv2_imshow

def image_resize(image, width = None, height = None, inter = cv2.INTER_AREA):
    # initialize the dimensions of the image to be resized and
    # grab the image size
    dim = None
    (h, w) = image.shape[:2]

    # if both the width and height are None, then return the
    # original image
    if width is None and height is None:
        return image

    # check to see if the width is None
    if width is None:
        # calculate the ratio of the height and construct the
        # dimensions
        r = height / float(h)
        dim = (int(w * r), height)

    # otherwise, the height is None
    else:
        # calculate the ratio of the width and construct the
        # dimensions
        r = width / float(w)
        dim = (width, int(h * r))

    # resize the image
    resized = cv2.resize(image, dim, interpolation = inter)

    # return the resized image
    return resized

def get_face_from_image(img):
  # resized_image = image_resize(img, width=1000)
  gray=cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
  face = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
  faces = face.detectMultiScale(gray, 1.2, 5)
  return (True, faces[0]) if len(faces)>0 else (False, None)

# %% [markdown]
# ## Train FER
# We do not necessarily need to train a new one. Just use the existing parameters for now. This section is useful for identifying the ConvNet structure used to train the model.
#
# Reference: Facial Emotion Recognition on FER2013 Dataset Using a Convolutional Neural Network
# https://github.com/gitshanks/fer2013

# %%
num_features = 64
num_labels = 7
batch_size = 64
epochs = 100
width, height = 48, 48

x = np.load(pathname+'fdataX.npy')
y = np.load(pathname+'flabels.npy')

x -= np.mean(x, axis=0)
x /= np.std(x, axis=0)

#splitting into training, validation and testing data
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.1, random_state=41)

#saving the test samples to be used later
np.save(pathname+'modXtest', X_test)
np.save(pathname+'modytest', y_test)

#desinging the CNN
def create_model(n_hidden_conv_layers = 3):
  model = Sequential()

  model.add(Conv2D(num_features, kernel_size=(3, 3), activation='relu', input_shape=(width, height, 1), data_format='channels_last', kernel_regularizer=l2(0.01)))
  model.add(Conv2D(num_features, kernel_size=(3, 3), activation='relu', padding='same'))
  model.add(BatchNormalization())
  model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
  model.add(Dropout(0.5))

  for i in range(n_hidden_conv_layers):
    model.add(Conv2D(2**(i+1)*num_features, kernel_size=(3, 3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(Conv2D(2**(i+1)*num_features, kernel_size=(3, 3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='same'))
    model.add(Dropout(0.5))

  model.add(Flatten())

  model.add(Dense(2*2*2*num_features, activation='relu'))
  model.add(Dropout(0.4)) #0.4
  model.add(Dense(2*2*num_features, activation='relu'))
  model.add(Dropout(0.4)) #0.4
  model.add(Dense(2*num_features, activation='relu'))
  model.add(Dropout(0.5)) #0.5

  model.add(Dense(num_labels, activation='softmax'))
  return model

# with strategy.scope():
model = create_model()
#Compliling the model with adam optimixer and categorical crossentropy loss
model.compile(loss=categorical_crossentropy,
              optimizer=Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07),
              metrics=['accuracy'])

# %%
#training the model
model.fit(np.array(X_train), np.array(y_train),
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(np.array(X_valid), np.array(y_valid)),
          shuffle=True)

#saving the  model to be used later
fer_json = model.to_json()
with open(pathname+"fer.json", "w") as json_file:
    json_file.write(fer_json)
model.save_weights(pathname+"fer.weights.h5")
print("Saved model to disk")
# Out:
# Epoch 1/100
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 1493s 3s/step - accuracy: 0.1977 - loss: 2.3293 - val_accuracy: 0.2594 - val_loss: 1.8249
# Epoch 2/100
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 1536s 3s/step - accuracy: 0.2597 - loss: 1.8015 - val_accuracy: 0.3198 - val_loss: 1.6704
# Epoch 3/100
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 1519s 3s/step - accuracy: 0.3045 - loss: 1.7225 - val_accuracy: 0.3498 - val_loss: 1.5769
# Epoch 4/100
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 1526s 3s/step - accuracy: 0.3639 - loss: 1.6124 - val_accuracy: 0.4043 - val_loss: 1.5047
# Epoch 5/100
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 1522s 3s/step - accuracy: 0.4082 - loss: 1.5085 - val_accuracy: 0.4334 - val_loss: 1.4185
# Epoch 6/100
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 1503s 3s/step - accuracy: 0.4378 - loss: 1.4463 - val_accuracy: 0.4644 - val_loss: 1.3585
# Epoch 7/100
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 1521s 3s/step - accuracy: 0.4496 - loss: 1.4131 - val_accuracy: 0.4929 - val_loss: 1.3564
# Epoch 8/100
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 1501s 3s/step - accuracy: 0.4654 - loss: 1.3891 - val_accuracy: 0.4972 - val_loss: 1.3042
# Epoch 9/100
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 1529s 3s/step - accuracy: 0.4789 - loss: 1.3525 - val_accuracy: 0.4913 - val_loss: 1.3452
# Epoch 10/100
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 1506s 3s/step - accuracy: 0.4882 - loss: 1.3421 - val_accuracy: 0.5365 - val_loss: 1.2295
# Epoch 11/100
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 1491s 3s/step - accuracy: 0.5092 - loss: 1.3088 - val_accuracy: 0.5396 - val_loss: 1.2167
# Epoch 12/100
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 1485s 3s/step - accuracy: 0.5176 - loss: 1.2766 - val_accuracy: 0.5461 - val_loss: 1.2091
# Epoch 13/100
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 1514s 3s/step - accuracy: 0.5309 - loss: 1.2504 - val_accuracy: 0.5545 - val_loss: 1.1986
# Epoch 14/100
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 1525s 3s/step - accuracy: 0.5351 - loss: 1.2351 - val_accuracy: 0.5563 - val_loss: 1.1555
# Epoch 15/100
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 1527s 3s/step - accuracy: 0.5496 - loss: 1.2114 - val_accuracy: 0.5762 - val_loss: 1.1555
# Epoch 16/100
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 1493s 3s/step - accuracy: 0.5579 - loss: 1.1894 - val_accuracy: 0.5762 - val_loss: 1.1623
# Epoch 17/100
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 1528s 3s/step - accuracy: 0.5693 - loss: 1.1726 - val_accuracy: 0.5885 - val_loss: 1.1056
# Epoch 18/100
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 1507s 3s/step - accuracy: 0.5826 - loss: 1.1491 - val_accuracy: 0.5876 - val_loss: 1.1209
# Epoch 19/100
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 1519s 3s/step - accuracy: 0.5876 - loss: 1.1201 - val_accuracy: 0.6003 - val_loss: 1.0972
# Epoch 20/100
#   5/455 ━━━━━━━━━━━━━━━━━━━━ 24:07 3s/step - accuracy: 0.6494 - loss: 0.9699

# %% [markdown]
# **Model Output**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Test FER

# %%
from keras.models import model_from_json, Sequential

pathname = '/content/drive/MyDrive/FIT3162/deep-lie/fer2013/'

# reads a model and its weights stored at path as name of file
# with .json for model and .h5 for weights
def load_model(path = pathname, file='fer'):
  json_file = open(path+file+'.json', 'r')
  loaded_model_json = json_file.read()
  json_file.close()
  loaded_model = model_from_json(loaded_model_json)
  # load weights into new model"
  loaded_model.load_weights(path+file+'.weights.h5')
  print("Loaded model from disk")
  return loaded_model

loaded_model = load_model()
# Out:
# Loaded model from disk

# %%
# load json and create model
from __future__ import division
from keras.models import Sequential
from keras.layers import Dense
from keras.models import model_from_json
import numpy
import os
import numpy as np

json_file = open(pathname+'fer.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights(pathname+"fer.weights.h5")
print("Loaded model from disk")

truey=[]
predy=[]
x = np.load(pathname+'modXtest.npy')
y = np.load(pathname+'modytest.npy')

yhat= loaded_model.predict(x)
yh = yhat.tolist()
yt = y.tolist()
count = 0

for i in range(len(y)):
    yy = max(yh[i])
    yyt = max(yt[i])
    predy.append(yh[i].index(yy))
    truey.append(yt[i].index(yyt))
    if(yh[i].index(yy)== yt[i].index(yyt)):
        count+=1

acc = (count/len(y))*100

#saving values for confusion matrix and analysis
np.save(pathname+'truey', truey)
np.save(pathname+'predy', predy)
print("Predicted and true label values saved")
print("Accuracy on test set :"+str(acc)+"%")
# Out:
# Loaded model from disk
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step
# Predicted and true label values saved
# Accuracy on test set :63.945388687656724%

# %% [markdown]
# ### Custom Test

# %%
# load json and create model
from __future__ import division
from keras.models import Sequential
from keras.layers import Dense
from keras.models import model_from_json
import numpy
import os
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

#loading the model
json_file = open(pathname+'fer.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights(pathname+"fer.weights.h5")
print("Loaded model from disk")

#setting image resizing parameters
WIDTH = 48
HEIGHT = 48
x=None
y=None
labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']

#loading image
test_path=pathname + 'Test Images/'
full_size_image = cv2.imread(test_path+'test.png')
full_size_image = image_resize(full_size_image, width=1000)
print("Image Loaded")
gray=cv2.cvtColor(full_size_image,cv2.COLOR_RGB2GRAY)
face = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
faces = face.detectMultiScale(gray, 1.3, 5)

#detecting faces
for (x, y, w, h) in faces:
        roi_gray = gray[y:y + h, x:x + w]
        cropped_img = np.expand_dims(np.expand_dims(cv2.resize(roi_gray, (48, 48)), -1), 0)
        cv2.normalize(cropped_img, cropped_img, alpha=0, beta=1, norm_type=cv2.NORM_L2, dtype=cv2.CV_32F)
        cv2.rectangle(full_size_image, (x, y), (x + w, y + h), (0, 255, 0), 1)
        #predicting the emotion
        yhat= loaded_model.predict(cropped_img)
        cv2.putText(full_size_image, labels[int(np.argmax(yhat))], (x, y), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 1, cv2.LINE_AA)
        print("Emotion: "+labels[int(np.argmax(yhat))])

cv2_imshow(full_size_image)
cv2.waitKey()
# Out:
# Loaded model from disk
# Image Loaded
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 740ms/step
# Emotion: Neutral
# <PIL.Image.Image image mode=RGB size=1000x750>
# -1

# %% [markdown]
# # Download datasets

# %%
import shutil
import os

def unzipAndReplace(folder_path, zip_path):
  if os.path.exists(folder_path):

    # Remove the directory and all its contents
    shutil.rmtree(folder_path)
    print(f"Directory '{folder_path}' and all its contents have been removed.")

  else:
      print(f"Directory '{folder_path}' does not exist.")

  # !unzip -q "dataset_300_retina_face.zip"
  print("Done unzip")

# %% [markdown]
# ## Download MU3D videos

# %%
# !gdown "https://drive.google.com/file/d/16wsovxe4EDGPBlz1t28xOq20s-vInEN7/view?usp=drive_link" --fuzzy
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=16wsovxe4EDGPBlz1t28xOq20s-vInEN7
# From (redirected): https://drive.google.com/uc?id=16wsovxe4EDGPBlz1t28xOq20s-vInEN7&confirm=t&uuid=62df9d0a-1743-4f71-a9fd-c2ef34fe31f4
# To: /content/Videos-20250304T061900Z-001.zip
# 100% 1.65G/1.65G [00:17<00:00, 91.8MB/s]

# %% [markdown]
# Delete ./Videos

# %%
unzipAndReplace("./Videos", "Videos-20250304T061900Z-001.zip")

# %% [markdown]
# ## Download preprocessed MU3D video frames (300/sample)

# %%
# !gdown "https://drive.google.com/file/d/1J73GPv7zC2rXq7rtMz7XgNPX2CIfQvjx/view?usp=drive_link" --fuzzy
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1J73GPv7zC2rXq7rtMz7XgNPX2CIfQvjx
# From (redirected): https://drive.google.com/uc?id=1J73GPv7zC2rXq7rtMz7XgNPX2CIfQvjx&confirm=t&uuid=8d2cec7e-d076-4bd4-987b-18d0eed06be2
# To: /content/dataset_300_retina_face.zip
# 100% 2.29G/2.29G [00:33<00:00, 68.9MB/s]

# %%
unzipAndReplace("./dataset_300_3_points", "dataset_300_retina_face.zip")
# Out:
# Directory './dataset_300_3_points' and all its contents have been removed.
# Done unzip

# %% [markdown]
# # Part 2: Lie Detection in Video

# %% [markdown]
# To calculate confusion matrix:

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(y_true, y_pred, labels = ['deceptive', 'truthful'], title='Confusion Matrix'):
  cm = confusion_matrix(y_true, y_pred)
  print(cm)

  plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
  plt.title(title)
  plt.colorbar()
  tick_marks = np.arange(len(labels))
  plt.xticks(tick_marks, labels, rotation=45)
  plt.yticks(tick_marks, labels)
  fmt = 'd'
  thresh = cm.max() / 2.
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
      plt.text(j, i, format(cm[i, j], fmt),
              horizontalalignment="center",
              color="white" if cm[i, j] > thresh else "black")

  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.tight_layout()
  plt.show()

# %% [markdown]
# Define paths to be used later

# %%
import pandas as pd

# define paths
drive_path = '/content/drive/MyDrive/FIT3162/deep-lie/'
video_path = "/content/Videos/"
frames_path_300 = "/content/dataset_300_3_points/"
project_path = drive_path + "Project/"
video_dir_path = project_path + "MU3D Codebook.xlsx"

# %% [markdown]
# Create a video dictionary to map IDs to labels

# %%
video_data = pd.read_excel(video_dir_path, sheet_name='Video-Level Data')

video_filenames = video_data['VideoID'].tolist()
labels = video_data['Veracity'].tolist()

video_dict = dict(zip(video_filenames, labels))
print(video_dict)
# Out:
# {'BF001_1PT': 1, 'BF001_2NL': 0, 'BF001_3NT': 1, 'BF001_4PL': 0, 'BF002_1PT': 1, 'BF002_2NL': 0, 'BF002_3NT': 1, 'BF002_4PL': 0, 'BF003_1PT': 1, 'BF003_2NL': 0, 'BF003_3NT': 1, 'BF003_4PL': 0, 'BF004_1PT': 1, 'BF004_2NL': 0, 'BF004_3NT': 1, 'BF004_4PL': 0, 'BF006_1PT': 1, 'BF006_2NL': 0, 'BF006_3NT': 1, 'BF006_4PL': 0, 'BF008_1PT': 1, 'BF008_2NL': 0, 'BF008_3NT': 1, 'BF008_4PL': 0, 'BF013_1PT': 1, 'BF013_2NL': 0, 'BF013_3NT': 1, 'BF013_4PL': 0, 'BF014_1PT': 1, 'BF014_2NL': 0, 'BF014_3NT': 1, 'BF014_4PL': 0, 'BF015_1PT': 1, 'BF015_2NL': 0, 'BF015_3NT': 1, 'BF015_4PL': 0, 'BF016_1PT': 1, 'BF016_2NL': 0, 'BF016_3NT': 1, 'BF016_4PL': 0, 'BF018_1PT': 1, 'BF018_2NL': 0, 'BF018_3NT': 1, 'BF018_4PL': 0, 'BF019_1PT': 1, 'BF019_2NL': 0, 'BF019_3NT': 1, 'BF019_4PL': 0, 'BF020_1PT': 1, 'BF020_2NL': 0, 'BF020_3NT': 1, 'BF020_4PL': 0, 'BF022_1PT': 1, 'BF022_2NL': 0, 'BF022_3NT': 1, 'BF022_4PL': 0, 'BF023_1PT': 1, 'BF023_2NL': 0, 'BF023_3NT': 1, 'BF023_4PL': 0, 'BF024_1PT': 1, 'BF024_2NL': 0, 'BF024_3NT': 1, 'BF024_4PL': 0, 'BF025_1PT': 1, 'BF025_2NL': 0, 'BF025_3NT': 1, 'BF025_4PL': 0, 'BF027_1PT': 1, 'BF027_2NL': 0, 'BF027_3NT': 1, 'BF027_4PL': 0, 'BF028_1PT': 1, 'BF028_2NL': 0, 'BF028_3NT': 1, 'BF028_4PL': 0, 'BF033_1PT': 1, 'BF033_2NL': 0, 'BF033_3NT': 1, 'BF033_4PL': 0, 'BM003_1PT': 1, 'BM003_2NL': 0, 'BM003_3NT': 1, 'BM003_4PL': 0, 'BM004_1PT': 1, 'BM004_2NL': 0, 'BM004_3NT': 1, 'BM004_4PL': 0, 'BM005_1PT': 1, 'BM005_2NL': 0, 'BM005_3NT': 1, 'BM005_4PL': 0, 'BM006_1PT': 1, 'BM006_2NL': 0, 'BM006_3NT': 1, 'BM006_4PL': 0, 'BM007_1PT': 1, 'BM007_2NL': 0, 'BM007_3NT': 1, 'BM007_4PL': 0, 'BM008_1PT': 1, 'BM008_2NL': 0, 'BM008_3NT': 1, 'BM008_4PL': 0, 'BM009_1PT': 1, 'BM009_2NL': 0, 'BM009_3NT': 1, 'BM009_4PL': 0, 'BM010_1PT': 1, 'BM010_2NL': 0, 'BM010_3NT': 1, 'BM
T': 1, 'WF023_2NL': 0, 'WF023_3NT': 1, 'WF023_4PL': 0, 'WF024_1PT': 1, 'WF024_2NL': 0, 'WF024_3NT': 1, 'WF024_4PL': 0, 'WF025_1PT': 1, 'WF025_2NL': 0, 'WF025_3NT': 1, 'WF025_4PL': 0, 'WM001_1PT': 1, 'WM001_2NL': 0, 'WM001_3NT': 1, 'WM001_4PL': 0, 'WM002_1PT': 1, 'WM002_2NL': 0, 'WM002_3NT': 1, 'WM002_4PL': 0, 'WM005_1PT': 1, 'WM005_2NL': 0, ...

# %% [markdown]
# ### Some helper functions and one-time read / write operations (don't worry about it)
# Define function to create paths, read and process videos

# %%
def create_path(path):
  try:
    if not os.path.exists(path):
      os.makedirs(path)
  except OSError:
    print(f"Error: Creating directory: {path}")

# %%
from alive_progress import alive_bar
from google.colab import output
output.enable_custom_widget_manager()

def preprocess_image(img):
  gray_img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY) # we turn the image to grayscale
  cropped_img = np.expand_dims(np.expand_dims(cv2.resize(gray_img, (48, 48)), -1), 0)
  cv2.normalize(cropped_img, cropped_img, alpha=0, beta=1, norm_type=cv2.NORM_L2, dtype=cv2.CV_32F)
  return cropped_img

# Using the 300 frames dataset
# Saves the cropped facial image
def read_video_300(filename):
    folder = os.path.join(frames_path_300, filename)
    frame_files = sorted(os.listdir(folder))

    # Initialize an array to store the flattened cropped images for 300 frames
    xdata = np.zeros((300, 48*48))
    frame_count = 0

    for frame_file in frame_files:
        if frame_count >= 300: break # limit the max number of frames we examine

        frame_path = os.path.join(folder, frame_file)
        frame_image = cv2.imread(frame_path)

        if frame_image is None: continue # skip frames cannot be loaded

        # Preprocess and flatten
        cropped_img = preprocess_image (frame_image) # resize/normalize to 48x48
        xdata[frame_count, :] = cropped_img.flatten()
        frame_count += 1

    # Release all space and windows once done
    cv2.destroyAllWindows()

    return xdata

def saveData(X, y):
  X = np.asarray(X)
  y = np.asarray(y)
  np.save(project_path+'fdataX', X)
  np.save(project_path+'flabels', y)


X = []
y = []

count = 0
with alive_bar(len(video_dict), force_tty=True) as bar:

  for (k, v) in video_dict.items():
    count+=1
    xi = read_video_300(k)
    X.append(xi)
    y.append(v)
    if count % 5 == 0:
      saveData(X, y)
    bar()

saveData(X, y)
print(f"\nComplete saving {count} number of data")
# Out:
# |████████████████████████████████████████| 320/320 [100%] in 4:14.9 (1.25/s)
#
# Complete saving 320 number of data

# %% [markdown]
# Visualise the dataset

# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.load(project_path + 'fdataX.npy')  # shape: (num_videos, 300, 48*48)
y = np.load(project_path + 'flabels.npy') # shape: (num_videos,)

def display_video_sample(video_index, num_frames=10):
    """
    Displays num_frames (evenly spaced) from the video sample at video_index.
    """
    # Get the video sample and its corresponding label
    video_data = X[video_index]  # shape: (300, 48*48)
    label = y[video_index]

    # Choose evenly spaced indices to display frames
    indices = np.linspace(0, video_data.shape[0] - 1, num_frames, dtype=int)

    # Create a figure with subplots
    fig, axs = plt.subplots(1, num_frames, figsize=(num_frames*2, 2.5))
    fig.suptitle(f"Video Index: {video_index} | Label: {label}", fontsize=14)

    # Iterate over selected frame indices and plot each frame
    for i, idx in enumerate(indices):
        frame = video_data[idx].reshape(48, 48)  # reshape from flattened to 48x48
        axs[i].imshow(frame, cmap='gray')
        axs[i].axis('off')
        axs[i].set_title(f"Frame {idx}")

    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.show()

# Example: Display sample frames for the first video (index 0)
display_video_sample(0)

# %% [markdown]
# ## Train DNN

# %%
import sys, os
import pandas as pd
import numpy as np

from tensorflow.keras import initializers
from keras.losses import binary_crossentropy
from sklearn.model_selection import train_test_split
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Flatten, Input, Masking, GRU
from keras.layers import Conv1D, Conv2D, Conv3D, MaxPooling1D, MaxPooling2D, MaxPooling3D, BatchNormalization
from keras.losses import categorical_crossentropy
from keras.optimizers import Adam
from keras.regularizers import l2
from keras.callbacks import ReduceLROnPlateau, TensorBoard, EarlyStopping, ModelCheckpoint
from keras.models import load_model
from keras.models import model_from_json
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
X = np.load(project_path+'fdataX.npy')
y = np.load(project_path+'flabels.npy')

print('Loaded data', X.shape, y.shape)
# Out:
# Loaded data (320, 300, 2304) (320,)

# %%
X = np.reshape(X,(X.shape[0], X.shape[1], 48, 48))
X = np.expand_dims(X, -1)
X.shape
# Out:
# (320, 300, 48, 48, 1)

# %% [markdown]
# ### Gated Recurrent Units (GRU) Model

# %%
from alive_progress import alive_bar
from google.colab import output
output.enable_custom_widget_manager()

# load the layers from the pre-trained, loaded model
layer_names = [layer.name for layer in loaded_model.layers]
layer_outputs = [layer.output for layer in loaded_model.layers]
print(f"layer_names total: {len(layer_names)}")

# pre-process input X
X -= np.mean(X, axis=0)
X /= (np.std(X, axis=0) + 1e-8)

# for each entry, we will convert each of the 300 images (48, 48, 1) to encoding vectors
encoding_model = Model(inputs = loaded_model.inputs, outputs = layer_outputs[23])

X_cnn = np.zeros((X.shape[0], X.shape[1], 4608))
i = 0
with alive_bar(len(X), force_tty=True) as bar:
  for (xi, yi) in zip(X, y):
    predictedX = encoding_model.predict(xi, verbose=0)
    X_cnn[i] = predictedX
    i+=1
    bar()

#splitting into training, validation and testing data
X_train, X_test, y_train, y_test = train_test_split(X_cnn, y, test_size=0.1, random_state=1) # random_state=42
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.1, random_state=7) # random_state=41

#saving the test samples to be used later
np.save(project_path+'modXtest', X_test)
np.save(project_path+'modytest', y_test)
# Out:
# layer_names total: 31
# |████████████████████████████████████████| 320/320 [100%] in 38.1s (8.39/s)

# %% [markdown]
# Visualise the encoded training data

# %%
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact

label_names = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']

def predict_expression(frame_48x48):
    """
    Predicts the facial expression using the loaded FER model.
    'frame_48x48' should be a 48x48 grayscale image (float32).
    Returns a string label for the top predicted emotion.
    """
    # Model expects (batch_size, 48, 48, 1) if that's how it was trained.
    # Expand dims to create batch and channel dimension.
    input_batch = np.expand_dims(frame_48x48, axis=-1)  # (48,48) -> (48,48,1)
    input_batch = np.expand_dims(input_batch, axis=0)   # -> (1,48,48,1)

    # Predict probabilities for each of the 7 classes
    probs = loaded_model.predict(input_batch, verbose=0)[0]  # shape (7,)
    top_idx = np.argmax(probs)
    return label_names[top_idx]

def display_video_with_encoding(video_index, num_frames=10):
    """
    Displays a sample video with:
      - Top row: Original frames (48x48) + predicted expression in title
      - Bottom row: Encoding heatmaps (reshaped to 64x72)
    """
    # Retrieve the video sample (300 frames) and its encoding
    video_frames = X[video_index]      # shape: (300, 48*48)
    encodings = X_cnn[video_index]     # shape: (300, 4608)

    # If y is one-hot or multi-hot, you can decode it;
    # otherwise, this might be an integer or string label already.
    # Here we just show the raw label as an example:
    raw_label = y[video_index]

    # Evenly spaced frame indices
    indices = np.linspace(0, video_frames.shape[0] - 1, num_frames, dtype=int)

    # Create a figure with two rows
    fig, axs = plt.subplots(2, num_frames, figsize=(num_frames*2, 5))
    fig.suptitle(f"Video Index: {video_index} | Label: {raw_label}", fontsize=16)

    for j, idx in enumerate(indices):
        # ----------------------------
        # TOP ROW: Original frame
        # ----------------------------
        # Convert flattened 48*48 to (48,48)
        frame_2d = video_frames[idx].reshape(48, 48).astype('float32')

        axs[0, j].imshow(frame_2d, cmap='gray')
        axs[0, j].axis('off')
        axs[0, j].set_title(f"Frame {idx}")

        # ----------------------------
        # BOTTOM ROW: Encoding heatmap
        # ----------------------------
        encoding_frame = encodings[idx].reshape(64, 72)
        # Predict the expression using the loaded FER model
        predicted_expr = predict_expression(frame_2d)
        im = axs[1, j].imshow(encoding_frame, cmap='viridis')
        axs[1, j].axis('off')
        axs[1, j].set_title(f"{predicted_expr}")


    plt.tight_layout(rect=[0, 0, 1, 1])
    plt.show()

display_video_with_encoding(0)

# %%
print(X_train.shape, y_train.shape)
m = X_train.shape[0]
Tx = X_train.shape[1]
dims = X_train.shape[2]
# Out:
# (259, 300, 4608) (259,)

# %%
# train a GRU network for binary classification
def create_gru_model(input_shape):
  X_input = Input(shape=input_shape)
  X = Conv1D(filters=196, kernel_size=15, strides=4)(X_input) #filters = 196, kernel_size = 15
  X = MaxPooling1D(pool_size=30, strides=15, padding='same')(X) # pool 30, strides 15 is fine!
  X = BatchNormalization()(X)
  X = Activation("relu")(X)
  X = Dropout(rate=0.8)(X)

  X = GRU(units=128, return_sequences=True)(X)
  X = Dropout(rate=0.8)(X)
  X = BatchNormalization()(X)

  # X = GRU(units=128, return_sequences=True)(X)
  X = GRU(units=128, return_sequences=False)(X)
  X = Dropout(rate=0.8)(X)
  X = BatchNormalization()(X)

  X = Dropout(rate=0.8)(X) #0.8 is fine!

  X = Dense(1, activation="sigmoid")(X)

  model = Model(inputs=X_input, outputs=X)

  return model

gru_model = create_gru_model(input_shape=(Tx, dims))
gru_model.summary()
# Out:
# Model: "functional_40"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_8 (InputLayer)           │ (None, 300, 4608)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_8 (Conv1D)                    │ (None, 72, 196)             │      13,547,716 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_8 (MaxPooling1D)       │ (None, 5, 196)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_22               │ (None, 5, 196)              │             784 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_8 (Activation)            │ (None, 5, 196)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_23 (Dropout)                 │ (None, 5, 196)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_14 (GRU)                         │ (None, 5, 128)              │         125,184 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_24 (Dropout)                 │ (None, 5, 128)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_23               │ (None, 5, 128)              │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_15 (GRU)                         │ (None, 128)                 │          99,072 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_25 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_24               │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_26 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 13,773,909 (52.54 MB)
#  Trainable params: 13,773,005 (52.54 MB)
#  Non-trainable params: 904 (3.53 KB)

# %%
print(np.array(X_train).shape)
print(np.array(y_train).shape)
# Out:
# (259, 300, 4608)
# (259,)

# %%
gru_model.compile(loss='binary_crossentropy', optimizer=Adam(
    learning_rate=0.001, # 0.001
    beta_1=0.9,
    beta_2=0.999,
    decay=0.01,  # 0.01
    epsilon=1e-7
  ), metrics=['accuracy'])

gru_model.fit(np.array(X_train), np.array(y_train),
          batch_size=64,
          epochs=150,
          verbose=1,
          validation_data=(np.array(X_valid), np.array(y_valid)),
          shuffle=True,
  )


# evaluate the keras model
_, accuracy = gru_model.evaluate(X_valid, y_valid)
acc_str = '%.2f' % (accuracy*100)
print(f'Accuracy: {acc_str}%')


#saving the  model to be used later
folder_path = "gru_model/"

gru_model_json = gru_model.to_json()
with open(project_path+folder_path+"gru_model_"+acc_str+".json", "w") as json_file:
    json_file.write(gru_model_json)
gru_model.save_weights(project_path+folder_path+"gru_model_"+acc_str+".weights.h5")
print("Saved gru_model to disk")
# Out:
# Epoch 1/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 409ms/step - accuracy: 0.5389 - loss: 1.2698 - val_accuracy: 0.4828 - val_loss: 0.7768
# Epoch 2/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - accuracy: 0.4820 - loss: 1.5628 - val_accuracy: 0.5172 - val_loss: 0.7850
# Epoch 3/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 0.4707 - loss: 1.3324 - val_accuracy: 0.4828 - val_loss: 0.8181
# Epoch 4/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 220ms/step - accuracy: 0.4755 - loss: 1.3310 - val_accuracy: 0.5172 - val_loss: 0.8376
# Epoch 5/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - accuracy: 0.4833 - loss: 1.4112 - val_accuracy: 0.4828 - val_loss: 0.8401
# Epoch 6/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 222ms/step - accuracy: 0.5361 - loss: 1.4150 - val_accuracy: 0.4828 - val_loss: 0.8465
# Epoch 7/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 222ms/step - accuracy: 0.4928 - loss: 1.3431 - val_accuracy: 0.4828 - val_loss: 0.8365
# Epoch 8/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 0.5031 - loss: 1.2641 - val_accuracy: 0.5172 - val_loss: 0.8158
# Epoch 9/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 220ms/step - accuracy: 0.5133 - loss: 1.3079 - val_accuracy: 0.5517 - val_loss: 0.7927
# Epoch 10/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 220ms/step - accuracy: 0.4673 - loss: 1.3731 - val_accuracy: 0.6207 - val_loss: 0.7804
# Epoch 11/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 222ms/step - accuracy: 0.5134 - loss: 1.3448 - val_accuracy: 0.6552 - val_loss: 0.7661
# Epoch 12/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 222ms/step - accuracy: 0.5720 - loss: 1.1527 - val_accuracy: 0.6552 - val_loss: 0.7569
# Epoch 13/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 221ms/step - accuracy: 0.4232 - loss: 1.2547 - val_accuracy: 0.6207 - val_loss: 0.7573
# Epoch 14/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 225ms/step - accuracy: 0.4740 - loss: 1.3070 - val_accuracy: 0.5517 - val_loss: 0.7523
# Epoch 15/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 227ms/step - accuracy: 0.5114 - loss: 1.2541 - val_accuracy: 0.5517 - val_loss: 0.7547
# Epoch 16/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 221ms/step - accuracy: 0.5117 - loss: 1.2284 - val_accuracy: 0.5172 - val_loss: 0.7622
# Epoch 17/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - accuracy: 0.5093 - loss: 1.2756 - val_accuracy: 0.5517 - val_loss: 0.7613
# Epoch 18/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 229ms/step - accuracy: 0.5039 - loss: 1.3358 - val_accuracy: 0.5517 - val_loss: 0.7559
# Epoch 19/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 222ms/step - accuracy: 0.5647 - loss: 0.9580 - val_accuracy: 0.5517 - val_loss: 0.7518
# Epoch 20/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 0.5436 - loss: 1.1395 - val_accuracy: 0.5517 - val_loss: 0.7520
# Epoch 21/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 220ms/step - accuracy: 0.5020 - loss: 1.2317 - val_accuracy: 0.5517 - val_loss: 0.7525
# Epoch 22/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 221ms/step - accuracy: 0.5413 - loss: 1.1487 - val_accuracy: 0.6207 - val_loss: 0.7508
# Epoch 23/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 222ms/step - accuracy: 0.5058 - loss: 1.0773 - val_accuracy: 0.6207 - val_loss: 0.7507
# Epoch 24/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 224ms/step - accuracy: 0.5363 - loss: 0.9707 - val_accuracy: 0.5517 - val_loss: 0.7516
# Epoch 25/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 222ms/step - accuracy: 0.5046 - loss: 1.1024 - val_accuracy: 0.6207 - val_loss: 0.7493
# Epoch 26/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 220ms/step - accuracy: 0.5108 - loss: 1.1327 - val_accuracy: 0.5862 - val_loss: 0.7659
# Epoch 27/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - accuracy: 0.

# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### Leave-one-out cross validation evaluation

# %% [markdown]
# According to "Video Based Deception Detection Using Deep Recurrent Convolutional Neural Network" (CVIP 2019) by Sushma Venkatesh, Raghavendra Ramachandra, Patrick Bours, using Leave-one-out cross validation across 25 trials, they have achieved 100% accuracy on the same dataset (121 trial videos) using Deep Recurrent Convolutional Neural Network.

# %%
import numpy as np
from sklearn.model_selection import LeaveOneOut
# X = np.array([[1, 2], [3, 4]])
# y = np.array([1, 2])
loo = LeaveOneOut()
loo.get_n_splits(X)
print(loo)

acc_per_trial = []
loss_per_trial = []

trial = 0
for train_index, test_index in loo.split(X_cnn):
    trial += 1
    X_train, X_valid = X_cnn[train_index], X_cnn[test_index]
    y_train, y_valid = y[train_index], y[test_index]

    gru_model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, decay=0.01, epsilon=1e-7), metrics=['accuracy'])
    history = gru_model.fit(np.array(X_train), np.array(y_train),
              batch_size=64,
              epochs=200, # 150
              verbose=1,
              validation_data=(np.array(X_valid), np.array(y_valid)),
              shuffle=True)
    scores = gru_model.evaluate(X_valid, y_valid, verbose=0)
    print(f'Score for trial {trial}: {gru_model.metrics_names[0]} of {scores[0]}; {gru_model.metrics_names[1]} of {scores[1]*100}%')
    acc_per_trial.append(scores[1] * 100)
    loss_per_trial.append(scores[0])


    # evaluate the keras model
    _, accuracy = gru_model.evaluate(X_valid, y_valid)
    acc_str = '%.2f' % (accuracy*100)
    print(f'Accuracy: {acc_str}%')

    if trial == 25: break # we only look at 25 trials



print('------------------------------------------------------------------------')
print('Score per trial')
for i in range(0, len(acc_per_trial)):
  print('------------------------------------------------------------------------')
  print(f'> Trial {i+1} - Loss: {loss_per_trial[i]} - Accuracy: {acc_per_trial[i]}%')
print('------------------------------------------------------------------------')
print('Average scores for all trial:')
acc_str = f'{np.mean(acc_per_trial)} (+- {np.std(acc_per_trial)})'
print(f'> Accuracy: {acc_str})')
print(f'> Loss: {np.mean(loss_per_trial)}')
print('------------------------------------------------------------------------')

folder_path = 'gru_model/'
loocv_gru_path = os.path.join(project_path, folder_path)
gru_model.save_weights(project_path+folder_path+"gru_model_(LOOCV)_"+acc_str+".weights.h5")

print(f"Scores and weights saved to: {folder_path}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 149/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9936 - loss: 0.0178 - val_accuracy: 1.0000 - val_loss: 2.1219e-08
# Epoch 150/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9858 - loss: 0.0191 - val_accuracy: 1.0000 - val_loss: 1.8624e-08
# Epoch 151/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 221ms/step - accuracy: 0.9961 - loss: 0.0051 - val_accuracy: 1.0000 - val_loss: 1.7144e-08
# Epoch 152/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 221ms/step - accuracy: 0.9910 - loss: 0.0148 - val_accuracy: 1.0000 - val_loss: 1.4590e-08
# Epoch 153/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 0.9785 - loss: 0.0305 - val_accuracy: 1.0000 - val_loss: 1.3475e-08
# Epoch 154/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9886 - loss: 0.0156 - val_accuracy: 1.0000 - val_loss: 1.2074e-08
# Epoch 155/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9979 - loss: 0.0054 - val_accuracy: 1.0000 - val_loss: 1.1042e-08
# Epoch 156/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 222ms/step - accuracy: 0.9935 - loss: 0.0093 - val_accuracy: 1.0000 - val_loss: 9.9409e-09
# Epoch 157/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 220ms/step - accuracy: 0.9974 - loss: 0.0048 - val_accuracy: 1.0000 - val_loss: 9.1817e-09
# Epoch 158/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - accuracy: 0.9833 - loss: 0.0293 - val_accuracy: 1.0000 - val_loss: 8.0553e-09
# Epoch 159/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 8.3034e-09
# Epoch 160/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9983 - loss: 0.0090 - val_accuracy: 1.0000 - val_loss: 8.1218e-09
# Epoch 161/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 213ms/step - accuracy: 0.9990 - loss: 0.0110 - val_accuracy: 1.0000 - val_loss: 7.9494e-09
# Epoch 162/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 1.0000 - val_loss: 8.2045e-09
# Epoch 163/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 0.9983 - loss: 0.0056 - val_accuracy: 1.0000 - val_loss: 8.6791e-09
# Epoch 164/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9884 - loss: 0.0271 - val_accuracy: 1.0000 - val_loss: 1.0900e-08
# Epoch 165/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9906 - loss: 0.0416 - val_accuracy: 1.0000 - val_loss: 1.3771e-08
# Epoch 166/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9810 - loss: 0.0302 - val_accuracy: 1.0000 - val_loss: 1.6326e-08
# Epoch 167/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9990 - loss: 0.0065 - val_accuracy: 1.0000 - val_loss: 2.0848e-08
# Epoch 168/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9957 - loss: 0.0455 - val_accuracy: 1.0000 - val_loss: 2.3736e-08
# Epoch 169/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9777 - loss: 0.0809 - val_accuracy: 1.0000 - val_loss: 1.8204e-08
# Epoch 170/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9876 - loss: 0.0293 - val_accuracy: 1.0000 - val_loss: 1.4980e-08
# Epoch 171/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9904 - loss: 0.0161 - val_accuracy: 1.0000 - val_loss: 1.4432e-08
# Epoch 172/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.9815 - loss: 0.1177 - val_accuracy: 1.0000 - val_loss: 1.5532e-08
# Epoch 173/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 1.0000 - val_loss: 1.6497e-08
# Epoch 174/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 1.0000 - val_loss: 1.6826e-08
# Epoch 175/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 0.9884 - loss: 0.0243 - val_accuracy: 1.0000 - val_loss: 1.5633e-08
# Epoch 176/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9861 - loss: 0.0273 - val_accuracy: 1.0000 - val_loss: 1.6183e-08
# Epoch 177/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 0.9961 - loss: 0.0058 - val_accuracy: 1.0000 - val_loss: 1.6321e-08
# Epoch 178/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 0.9961 - loss: 0.0054 - val_accuracy: 1.0000 - val_loss: 1.6922e-08
# Epoch 179/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9850 - loss: 0.0325 - val_accuracy: 1.0000 - val_loss: 1.6765e-08
# Epoch 180/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 1.0000 - loss: 0.0102 - val_accuracy: 1.0000 - val_loss: 1.5310e-08
# Epoch 181/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9973 - loss: 0.0078 - val_accuracy: 1.0000 - val_loss: 1.4552e-08
# Epoch 182/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9935 - loss: 0.0146 - val_accuracy: 1.0000 - val_loss: 1.4671e-08
# Epoch 183/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 222ms/step - accuracy: 0.9961 - loss: 0.0101 - val_accuracy: 1.0000 - val_loss: 1.4781e-08
# Epoch 184/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9983 - loss: 0.0062 - val_accuracy: 1.0000 - val_loss: 1.5055e-08
# Epoch 185/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 220ms/step - accuracy: 0.9990 - loss: 0.0051 - val_accuracy: 1.0000 - val_loss: 1.5164e-08
# Epoch 186/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 1.0000 - val_loss: 1.5261e-08
# Epoch 187/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9910 - loss: 0.0144 - val_accuracy: 1.0000 - val_loss: 1.4772e-08
# Epoch 188/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 1.0000 - val_loss: 1.4378e-08
# Epoch 189/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 1.0000 - val_loss: 1.3760e-08
# Epoch 190/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9939 - loss: 0.0149 - val_accuracy: 1.0000 - val_loss: 1.2997e-08
# Epoch 191/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 220ms/step - accuracy: 0.9979 - loss: 0.0061 - val_accuracy: 1.0000 - val_loss: 1.2564e-08
# Epoch 192/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9961 - loss: 0.0071 - val_accuracy: 1.0000 - val_loss: 1.1494e-08
# Epoch 193/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9785 - loss: 0.0316 - val_accuracy: 1.0000 - val_loss: 1.0475e-08
# Epoch 194/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9918 - loss: 0.0122 - val_accuracy: 1.0000 - val_loss: 1.1074e-08
# Epoch 195/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 1.1362e-08
# Epoch 196/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9833 - loss: 0.1573 - val_accuracy: 1.0000 - val_loss: 1.3342e-08
# Epoch 197/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 1.0000 - val_loss: 1.5245e-08
# Epoch 198/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9807 - loss: 0.0926 - val_accuracy: 1.0000 - val_loss: 1.8327e-08
# Epoch 199/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 1.0000 - val_loss: 2.0578e-08
# Epoch 200/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9990 - loss: 0.0118 - val_accuracy: 1.0000 - val_loss: 2.1539e-08
# Score for trial 13: loss of 2.1538633987461253e-08; compile_metrics of 100.0%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 2.1539e-08
# Accuracy: 100.00%
# Epoch 1/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 314ms/step - accuracy: 0.9772 - loss: 0.0552 - val_accuracy: 1.0000 - val_loss: 3.3469e-08
# Epoch 2/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9990 - loss: 0.0050 - val_accuracy: 1.0000 - val_loss: 3.6239e-08
# Epoch 3/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.9941 - loss: 0.0499 - val_accuracy: 1.0000 - val_loss: 3.5028e-08
# Epoch 4/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9951 - loss: 0.0123 - val_accuracy: 1.0000 - val_loss: 4.2539e-08
# Epoch 5/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9822 - loss: 0.0455 - val_accuracy: 1.0000 - val_loss: 4.8181e-08
# Epoch 6/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9951 - loss: 0.0137 - val_accuracy: 1.0000 - val_loss: 4.8699e-08
# Epoch 7/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 213ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 1.0000 - val_loss: 4.6526e-08
# Epoch 8/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.9927 - loss: 0.0170 - val_accuracy: 1.0000 - val_loss: 4.0674e-08
# Epoch 9/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 1.0000 - val_loss: 3.5505e-08
# Epoch 10/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9899 - loss: 0.0747 - val_accuracy: 1.0000 - val_loss: 3.3754e-08
# Epoch 11/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9827 - loss: 0.0975 - val_accuracy: 1.0000 - val_loss: 3.2039e-08
# Epoch 12/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 1.0000 - val_loss: 3.5450e-08
# Epoch 13/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.9962 - loss: 0.0299 - val_accuracy: 1.0000 - val_loss: 3.7486e-08
# Epoch 14/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9935 - loss: 0.0183 - val_accuracy: 1.0000 - val_loss: 3.9811e-08
# Epoch 15/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9966 - loss: 0.0100 - val_accuracy: 1.0000 - val_loss: 4.1192e-08
# Epoch 16/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - accuracy: 0.9973 - loss: 0.0098 - val_accuracy: 1.0000 - val_loss: 4.1370e-08
# Epoch 17/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 1.0000 - val_loss: 4.0210e-08
# Epoch 18/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 0.9983 - loss: 0.0049 - val_accuracy: 1.0000 - val_loss: 4.0234e-08
# Epoch 19/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9951 - loss: 0.0076 - val_accuracy: 1.0000 - val_loss: 4.0890e-08
# Epoch 20/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.9949 - loss: 0.0103 - val_accuracy: 1.0000 - val_loss: 4.0618e-08
# Epoch 21/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 211ms/step - accuracy: 0.9961 - loss: 0.0152 - val_accuracy: 1.0000 - val_loss: 4.0509e-08
# Epoch 22/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 1.0000 - val_loss: 3.8782e-08
# Epoch 23/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9961 - loss: 0.0067 - val_accuracy: 1.0000 - val_loss: 3.4740e-08
# Epoch 24/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9964 - loss: 0.0168 - val_accuracy: 1.0000 - val_loss: 3.0985e-08
# Epoch 25/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9914 - loss: 0.0132 - val_accuracy: 1.0000 - val_loss: 2.9888e-08
# Epoch 26/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 220ms/step - accuracy: 0.9961 - loss: 0.0131 - val_accuracy: 1.0000 - val_loss: 2.9053e-08
# Epoch 27/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - accuracy: 0.9886 - loss: 0.0191 - val_accuracy: 1.0000 - val_loss: 2.6105e-08
# Epoch 28/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 1.0000 - val_loss: 2.4515e-08
# Epoch 29/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 0.9983 - loss: 0.0115 - val_accuracy: 1.0000 - val_loss: 2.1620e-08
# Epoch 30/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9911 - loss: 0.0480 - val_accuracy: 1.0000 - val_loss: 2.1087e-08
# Epoch 31/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 0.9908 - loss: 0.0240 - val_accuracy: 1.0000 - val_loss: 2.3917e-08
# Epoch 32/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9871 - loss: 0.0348 - val_accuracy: 1.0000 - val_loss: 2.5977e-08
# Epoch 33/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9900 - loss: 0.0247 - val_accuracy: 1.0000 - val_loss: 2.5489e-08
# Epoch 34/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9974 - loss: 0.0094 - val_accuracy: 1.0000 - val_loss: 2.6510e-08
# Epoch 35/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.9910 - loss: 0.0159 - val_accuracy: 1.0000 - val_loss: 2.6722e-08
# Epoch 36/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9781 - loss: 0.0308 - val_accuracy: 1.0000 - val_loss: 2.3908e-08
# Epoch 37/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9915 - loss: 0.0155 - val_accuracy: 1.0000 - val_loss: 2.2585e-08
# Epoch 38/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9961 - loss: 0.0080 - val_accuracy: 1.0000 - val_loss: 2.3776e-08
# Epoch 39/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9990 - loss: 0.0039 - val_accuracy: 1.0000 - val_loss: 2.3721e-08
# Epoch 40/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.9897 - loss: 0.0272 - val_accuracy: 1.0000 - val_loss: 2.3171e-08
# Epoch 41/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9841 - loss: 0.0266 - val_accuracy: 1.0000 - val_loss: 2.3309e-08
# Epoch 42/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 1.0000 - val_loss: 2.3648e-08
# Epoch 43/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 1.0000 - val_loss: 2.2370e-08
# Epoch 44/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 1.0000 - val_loss: 2.0792e-08
# Epoch 45/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 0.9897 - loss: 0.0259 - val_accuracy: 1.0000 - val_loss: 1.8764e-08
# Epoch 46/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 1.0000 - val_loss: 1.7286e-08
# Epoch 47/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9990 - loss: 0.0031 - val_accuracy: 1.0000 - val_loss: 1.6405e-08
# Epoch 48/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9983 - loss: 0.0044 - val_accuracy: 1.0000 - val_loss: 1.4990e-08
# Epoch 49/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 213ms/step - accuracy: 0.9961 - loss: 0.0089 - val_accuracy: 1.0000 - val_loss: 1.4117e-08
# Epoch 50/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9910 - loss: 0.0190 - val_accuracy: 1.0000 - val_loss: 1.4459e-08
# Epoch 51/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 1.0000 - val_loss: 1.5129e-08
# Epoch 52/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9935 - loss: 0.0220 - val_accuracy: 1.0000 - val_loss: 1.4698e-08
# Epoch 53/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 214ms/step - accuracy: 0.9964 - loss: 0.0054 - val_accuracy: 1.0000 - val_loss: 1.5073e-08
# Epoch 54/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9886 - loss: 0.0304 - val_accuracy: 1.0000 - val_loss: 1.4706e-08
# Epoch 55/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9983 - loss: 0.0081 - val_accuracy: 1.0000 - val_loss: 1.5012e-08
# Epoch 56/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9990 - loss: 0.0063 - val_accuracy: 1.0000 - val_loss: 1.5370e-08
# Epoch 57/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 0.9990 - loss: 0.0041 - val_accuracy: 1.0000 - val_loss: 1.5524e-08
# Epoch 58/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9961 - loss: 0.0078 - val_accuracy: 1.0000 - val_loss: 1.6255e-08
# Epoch 59/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 1.0000 - val_loss: 1.6587e-08
# Epoch 60/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.9884 - loss: 0.0624 - val_accuracy: 1.0000 - val_loss: 1.5480e-08
# Epoch 61/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9974 - loss: 0.0070 - val_accuracy: 1.0000 - val_loss: 1.5088e-08
# Epoch 62/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9935 - loss: 0.0121 - val_accuracy: 1.0000 - val_loss: 1.4339e-08
# Epoch 63/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 1.0000 - val_loss: 1.3986e-08
# Epoch 64/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 1.0000 - val_loss: 1.4433e-08
# Epoch 65/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9957 - loss: 0.0072 - val_accuracy: 1.0000 - val_loss: 1.5011e-08
# Epoch 66/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.9957 - loss: 0.0453 - val_accuracy: 1.0000 - val_loss: 1.6643e-08
# Epoch 67/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9893 - loss: 0.0138 - val_accuracy: 1.0000 - val_loss: 1.6864e-08
# Epoch 68/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 1.0000 - val_loss: 1.8677e-08
# Epoch 69/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 213ms/step - accuracy: 0.9961 - loss: 0.0120 - val_accuracy: 1.0000 - val_loss: 2.2835e-08
# Epoch 70/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 2.6253e-08
# Epoch 71/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9961 - loss: 0.0108 - val_accuracy: 1.0000 - val_loss: 2.7391e-08
# Epoch 72/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9809 - loss: 0.0391 - val_accuracy: 1.0000 - val_loss: 2.1927e-08
# Epoch 73/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9880 - loss: 0.0214 - val_accuracy: 1.0000 - val_loss: 1.9750e-08
# Epoch 74/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - accuracy: 0.9923 - loss: 0.0229 - val_accuracy: 1.0000 - val_loss: 1.8224e-08
# Epoch 75/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9935 - loss: 0.0125 - val_accuracy: 1.0000 - val_loss: 1.7110e-08
# Epoch 76/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - accuracy: 0.9897 - loss: 0.0396 - val_accuracy: 1.0000 - val_loss: 1.5268e-08
# Epoch 77/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9918 - loss: 0.0112 - val_accuracy: 1.0000 - val_loss: 1.4964e-08
# Epoch 78/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9845 - loss: 0.0372 - val_accuracy: 1.0000 - val_loss: 1.4023e-08
# Epoch 79/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - accuracy: 0.9961 - loss: 0.0149 - val_accuracy: 1.0000 - val_loss: 1.4340e-08
# Epoch 80/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9806 - loss: 0.0460 - val_accuracy: 1.0000 - val_loss: 1.6908e-08
# Epoch 81/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 222ms/step - accuracy: 0.9983 - loss: 0.0116 - val_accuracy: 1.0000 - val_loss: 1.8318e-08
# Epoch 82/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 0.9880 - loss: 0.0563 - val_accuracy: 1.0000 - val_loss: 1.9352e-08
# Epoch 83/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9871 - loss: 0.0184 - val_accuracy: 1.0000 - val_loss: 1.9304e-08
# Epoch 84/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 0.9935 - loss: 0.0134 - val_accuracy: 1.0000 - val_loss: 2.0309e-08
# Epoch 85/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9974 - loss: 0.0038 - val_accuracy: 1.0000 - val_loss: 2.2425e-08
# Epoch 86/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 1.0000 - loss: 0.0085 - val_accuracy: 1.0000 - val_loss: 2.2277e-08
# Epoch 87/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 220ms/step - accuracy: 0.9837 - loss: 0.0257 - val_accuracy: 1.0000 - val_loss: 2.4088e-08
# Epoch 88/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9973 - loss: 0.0169 - val_accuracy: 1.0000 - val_loss: 2.2552e-08
# Epoch 89/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9932 - loss: 0.0482 - val_accuracy: 1.0000 - val_loss: 1.9724e-08
# Epoch 90/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9990 - loss: 0.0081 - val_accuracy: 1.0000 - val_loss: 1.8871e-08
# Epoch 91/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9990 - loss: 0.0100 - val_accuracy: 1.0000 - val_loss: 1.8541e-08
# Epoch 92/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9961 - loss: 0.0112 - val_accuracy: 1.0000 - val_loss: 1.8063e-08
# Epoch 93/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9947 - loss: 0.0147 - val_accuracy: 1.0000 - val_loss: 1.7772e-08
# Epoch 94/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 1.0000 - val_loss: 1.7335e-08
# Epoch 95/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 0.9796 - loss: 0.0414 - val_accuracy: 1.0000 - val_loss: 1.7876e-08
# Epoch 96/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 0.9964 - loss: 0.0111 - val_accuracy: 1.0000 - val_loss: 1.7656e-08
# Epoch 97/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 220ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 1.0000 - val_loss: 1.7163e-08
# Epoch 98/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9957 - loss: 0.0178 - val_accuracy: 1.0000 - val_loss: 1.6261e-08
# Epoch 99/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 1.0000 - val_loss: 1.5489e-08
# Epoch 100/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9953 - loss: 0.0302 - val_accuracy: 1.0000 - val_loss: 1.4968e-08
# Epoch 101/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9957 - loss: 0.0125 - val_accuracy: 1.0000 - val_loss: 1.5131e-08
# Epoch 102/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 1.0000 - val_loss: 1.5664e-08
# Epoch 103/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9974 - loss: 0.0053 - val_accuracy: 1.0000 - val_loss: 1.6531e-08
# Epoch 104/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 213ms/step - accuracy: 0.9935 - loss: 0.0138 - val_accuracy: 1.0000 - val_loss: 1.7249e-08
# Epoch 105/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 220ms/step - accuracy: 0.9871 - loss: 0.1052 - val_accuracy: 1.0000 - val_loss: 1.7167e-08
# Epoch 106/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9919 - loss: 0.0175 - val_accuracy: 1.0000 - val_loss: 1.7217e-08
# Epoch 107/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 213ms/step - accuracy: 0.9983 - loss: 0.0146 - val_accuracy: 1.0000 - val_loss: 1.7946e-08
# Epoch 108/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9983 - loss: 0.0096 - val_accuracy: 1.0000 - val_loss: 1.8124e-08
# Epoch 109/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9983 - loss: 0.0065 - val_accuracy: 1.0000 - val_loss: 1.7867e-08
# Epoch 110/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 213ms/step - accuracy: 0.9936 - loss: 0.0102 - val_accuracy: 1.0000 - val_loss: 1.7590e-08
# Epoch 111/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9947 - loss: 0.0189 - val_accuracy: 1.0000 - val_loss: 1.8484e-08
# Epoch 112/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 1.0000 - loss: 0.0141 - val_accuracy: 1.0000 - val_loss: 2.0048e-08
# Epoch 113/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 1.0000 - val_loss: 2.1881e-08
# Epoch 114/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 1.0000 - val_loss: 2.2936e-08
# Epoch 115/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9974 - loss: 0.0126 - val_accuracy: 1.0000 - val_loss: 2.1929e-08
# Epoch 116/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 1.0000 - val_loss: 1.9138e-08
# Epoch 117/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.9927 - loss: 0.0335 - val_accuracy: 1.0000 - val_loss: 1.7686e-08
# Epoch 118/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9923 - loss: 0.0199 - val_accuracy: 1.0000 - val_loss: 1.7529e-08
# Epoch 119/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.9918 - loss: 0.0204 - val_accuracy: 1.0000 - val_loss: 1.7306e-08
# Epoch 120/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 1.0000 - val_loss: 1.7813e-08
# Epoch 121/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9935 - loss: 0.0108 - val_accuracy: 1.0000 - val_loss: 1.7786e-08
# Epoch 122/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9884 - loss: 0.0264 - val_accuracy: 1.0000 - val_loss: 1.7776e-08
# Epoch 123/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9966 - loss: 0.0074 - val_accuracy: 1.0000 - val_loss: 1.8161e-08
# Epoch 124/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9871 - loss: 0.0258 - val_accuracy: 1.0000 - val_loss: 1.9199e-08
# Epoch 125/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9974 - loss: 0.0072 - val_accuracy: 1.0000 - val_loss: 1.8737e-08
# Epoch 126/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 1.0000 - loss: 0.0086 - val_accuracy: 1.0000 - val_loss: 1.8434e-08
# Epoch 127/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9832 - loss: 0.0641 - val_accuracy: 1.0000 - val_loss: 2.1763e-08
# Epoch 128/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9961 - loss: 0.0056 - val_accuracy: 1.0000 - val_loss: 2.4563e-08
# Epoch 129/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9990 - loss: 0.0072 - val_accuracy: 1.0000 - val_loss: 2.5603e-08
# Epoch 130/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9966 - loss: 0.0124 - val_accuracy: 1.0000 - val_loss: 2.4520e-08
# Epoch 131/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 1.0000 - val_loss: 2.2703e-08
# Epoch 132/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9974 - loss: 0.0082 - val_accuracy: 1.0000 - val_loss: 2.0840e-08
# Epoch 133/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 1.0000 - val_loss: 1.9353e-08
# Epoch 134/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9974 - loss: 0.0030 - val_accuracy: 1.0000 - val_loss: 1.8597e-08
# Epoch 135/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - accuracy: 0.9951 - loss: 0.0192 - val_accuracy: 1.0000 - val_loss: 1.7487e-08
# Epoch 136/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9962 - loss: 0.0236 - val_accuracy: 1.0000 - val_loss: 1.6065e-08
# Epoch 137/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9961 - loss: 0.0113 - val_accuracy: 1.0000 - val_loss: 1.6220e-08
# Epoch 138/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9884 - loss: 0.0207 - val_accuracy: 1.0000 - val_loss: 1.6239e-08
# Epoch 139/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9918 - loss: 0.0106 - val_accuracy: 1.0000 - val_loss: 1.5684e-08
# Epoch 140/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9962 - loss: 0.0100 - val_accuracy: 1.0000 - val_loss: 1.4883e-08
# Epoch 141/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9940 - loss: 0.0186 - val_accuracy: 1.0000 - val_loss: 1.3615e-08
# Epoch 142/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 1.0000 - val_loss: 1.2505e-08
# Epoch 143/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9815 - loss: 0.0310 - val_accuracy: 1.0000 - val_loss: 1.2046e-08
# Epoch 144/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9983 - loss: 0.0104 - val_accuracy: 1.0000 - val_loss: 1.2221e-08
# Epoch 145/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9983 - loss: 0.0058 - val_accuracy: 1.0000 - val_loss: 1.3083e-08
# Epoch 146/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9983 - loss: 0.0069 - val_accuracy: 1.0000 - val_loss: 1.2823e-08
# Epoch 147/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 1.0000 - val_loss: 1.2695e-08
# Epoch 148/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9961 - loss: 0.0056 - val_accuracy: 1.0000 - val_loss: 1.3115e-08
# Epoch 149/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 1.0000 - val_loss: 1.2631e-08
# Epoch 150/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 221ms/step - accuracy: 0.9913 - loss: 0.0206 - val_accuracy: 1.0000 - val_loss: 1.2866e-08
# Epoch 151/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9935 - loss: 0.0252 - val_accuracy: 1.0000 - val_loss: 1.4795e-08
# Epoch 152/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.9895 - loss: 0.0185 - val_accuracy: 1.0000 - val_loss: 1.7065e-08
# Epoch 153/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 1.0000 - loss: 0.0072 - val_accuracy: 1.0000 - val_loss: 1.8003e-08
# Epoch 154/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 223ms/step - accuracy: 0.9935 - loss: 0.0159 - val_accuracy: 1.0000 - val_loss: 1.9076e-08
# Epoch 155/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9957 - loss: 0.0110 - val_accuracy: 1.0000 - val_loss: 1.9321e-08
# Epoch 156/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.9935 - loss: 0.0087 - val_accuracy: 1.0000 - val_loss: 1.8640e-08
# Epoch 157/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9990 - loss: 0.0068 - val_accuracy: 1.0000 - val_loss: 1.8724e-08
# Epoch 158/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9897 - loss: 0.0616 - val_accuracy: 1.0000 - val_loss: 1.9356e-08
# Epoch 159/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9974 - loss: 0.0080 - val_accuracy: 1.0000 - val_loss: 1.9753e-08
# Epoch 160/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.9974 - loss: 0.0113 - val_accuracy: 1.0000 - val_loss: 1.8810e-08
# Epoch 161/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 0.9763 - loss: 0.0395 - val_accuracy: 1.0000 - val_loss: 1.7160e-08
# Epoch 162/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9935 - loss: 0.0091 - val_accuracy: 1.0000 - val_loss: 1.6902e-08
# Epoch 163/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.9961 - loss: 0.0109 - val_accuracy: 1.0000 - val_loss: 1.6004e-08
# Epoch 164/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.9961 - loss: 0.0069 - val_accuracy: 1.0000 - val_loss: 1.5109e-08
# Epoch 165/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9983 - loss: 0.0053 - val_accuracy: 1.0000 - val_loss: 1.4914e-08
# Epoch 166/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 0.9854 - loss: 0.0360 - val_accuracy: 1.0000 - val_loss: 1.4886e-08
# Epoch 167/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9974 - loss: 0.0108 - val_accuracy: 1.0000 - val_loss: 1.4373e-08
# Epoch 168/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9893 - loss: 0.0222 - val_accuracy: 1.0000 - val_loss: 1.5041e-08
# Epoch 169/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 1.0000 - val_loss: 1.5032e-08
# Epoch 170/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9935 - loss: 0.0216 - val_accuracy: 1.0000 - val_loss: 1.4702e-08
# Epoch 171/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9962 - loss: 0.0113 - val_accuracy: 1.0000 - val_loss: 1.4011e-08
# Epoch 172/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9832 - loss: 0.0316 - val_accuracy: 1.0000 - val_loss: 1.3222e-08
# Epoch 173/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9918 - loss: 0.0249 - val_accuracy: 1.0000 - val_loss: 1.2870e-08
# Epoch 174/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.9884 - loss: 0.0317 - val_accuracy: 1.0000 - val_loss: 1.3956e-08
# Epoch 175/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9917 - loss: 0.0379 - val_accuracy: 1.0000 - val_loss: 1.5360e-08
# Epoch 176/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 1.0000 - loss: 0.0098 - val_accuracy: 1.0000 - val_loss: 1.6925e-08
# Epoch 177/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9897 - loss: 0.0416 - val_accuracy: 1.0000 - val_loss: 1.7912e-08
# Epoch 178/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.9925 - loss: 0.0137 - val_accuracy: 1.0000 - val_loss: 1.8314e-08
# Epoch 179/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 220ms/step - accuracy: 0.9910 - loss: 0.0588 - val_accuracy: 1.0000 - val_loss: 1.8714e-08
# Epoch 180/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9990 - loss: 0.0068 - val_accuracy: 1.0000 - val_loss: 1.8920e-08
# Epoch 181/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9983 - loss: 0.0128 - val_accuracy: 1.0000 - val_loss: 1.9028e-08
# Epoch 182/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9935 - loss: 0.0090 - val_accuracy: 1.0000 - val_loss: 1.8141e-08
# Epoch 183/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9935 - loss: 0.0146 - val_accuracy: 1.0000 - val_loss: 1.6487e-08
# Epoch 184/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - accuracy: 0.9957 - loss: 0.0160 - val_accuracy: 1.0000 - val_loss: 1.4181e-08
# Epoch 185/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9969 - loss: 0.0144 - val_accuracy: 1.0000 - val_loss: 1.2591e-08
# Epoch 186/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9910 - loss: 0.0192 - val_accuracy: 1.0000 - val_loss: 1.3729e-08
# Epoch 187/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9974 - loss: 0.0086 - val_accuracy: 1.0000 - val_loss: 1.4456e-08
# Epoch 188/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 1.0000 - val_loss: 1.4333e-08
# Epoch 189/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 1.0000 - loss: 0.0100 - val_accuracy: 1.0000 - val_loss: 1.4305e-08
# Epoch 190/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 1.0000 - val_loss: 1.4636e-08
# Epoch 191/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 0.9893 - loss: 0.0158 - val_accuracy: 1.0000 - val_loss: 1.4710e-08
# Epoch 192/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 1.0000 - val_loss: 1.4223e-08
# Epoch 193/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9983 - loss: 0.0041 - val_accuracy: 1.0000 - val_loss: 1.3828e-08
# Epoch 194/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 0.9979 - loss: 0.0162 - val_accuracy: 1.0000 - val_loss: 1.3002e-08
# Epoch 195/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - accuracy: 0.9964 - loss: 0.0097 - val_accuracy: 1.0000 - val_loss: 1.1731e-08
# Epoch 196/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9961 - loss: 0.0141 - val_accuracy: 1.0000 - val_loss: 1.0371e-08
# Epoch 197/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 1.0000 - val_loss: 9.6422e-09
# Epoch 198/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 1.0000 - val_loss: 9.3393e-09
# Epoch 199/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9910 - loss: 0.0161 - val_accuracy: 1.0000 - val_loss: 8.8978e-09
# Epoch 200/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 1.0000 - val_loss: 9.2307e-09
# Score for trial 14: loss of 9.23072196457042e-09; compile_metrics of 100.0%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 9.2307e-09
# Accuracy: 100.00%
# Epoch 1/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 310ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 1.0000 - val_loss: 1.5942e-08
# Epoch 2/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9983 - loss: 0.0057 - val_accuracy: 1.0000 - val_loss: 1.6702e-08
# Epoch 3/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 0.9956 - loss: 0.0183 - val_accuracy: 1.0000 - val_loss: 1.6126e-08
# Epoch 4/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9914 - loss: 0.0925 - val_accuracy: 1.0000 - val_loss: 1.6338e-08
# Epoch 5/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9990 - loss: 0.0040 - val_accuracy: 1.0000 - val_loss: 1.8367e-08
# Epoch 6/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9983 - loss: 0.0130 - val_accuracy: 1.0000 - val_loss: 2.1486e-08
# Epoch 7/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 1.0000 - val_loss: 2.1370e-08
# Epoch 8/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9974 - loss: 0.0078 - val_accuracy: 1.0000 - val_loss: 1.9152e-08
# Epoch 9/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9884 - loss: 0.0159 - val_accuracy: 1.0000 - val_loss: 1.5112e-08
# Epoch 10/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 1.0000 - val_loss: 1.3642e-08
# Epoch 11/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9983 - loss: 0.0095 - val_accuracy: 1.0000 - val_loss: 1.2554e-08
# Epoch 12/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9974 - loss: 0.0418 - val_accuracy: 1.0000 - val_loss: 1.2454e-08
# Epoch 13/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.9949 - loss: 0.0098 - val_accuracy: 1.0000 - val_loss: 1.3996e-08
# Epoch 14/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9841 - loss: 0.0352 - val_accuracy: 1.0000 - val_loss: 1.5402e-08
# Epoch 15/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9897 - loss: 0.0120 - val_accuracy: 1.0000 - val_loss: 1.5718e-08
# Epoch 16/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9832 - loss: 0.0593 - val_accuracy: 1.0000 - val_loss: 1.3883e-08
# Epoch 17/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9897 - loss: 0.0249 - val_accuracy: 1.0000 - val_loss: 1.3421e-08
# Epoch 18/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9944 - loss: 0.0095 - val_accuracy: 1.0000 - val_loss: 1.2440e-08
# Epoch 19/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9961 - loss: 0.0248 - val_accuracy: 1.0000 - val_loss: 1.2154e-08
# Epoch 20/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - accuracy: 0.9966 - loss: 0.0087 - val_accuracy: 1.0000 - val_loss: 1.1377e-08
# Epoch 21/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 221ms/step - accuracy: 0.9936 - loss: 0.0142 - val_accuracy: 1.0000 - val_loss: 1.0453e-08
# Epoch 22/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9990 - loss: 0.0057 - val_accuracy: 1.0000 - val_loss: 1.0061e-08
# Epoch 23/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 1.0000 - val_loss: 9.1228e-09
# Epoch 24/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9936 - loss: 0.0114 - val_accuracy: 1.0000 - val_loss: 9.1073e-09
# Epoch 25/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 1.0000 - val_loss: 9.4234e-09
# Epoch 26/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9974 - loss: 0.0108 - val_accuracy: 1.0000 - val_loss: 8.8792e-09
# Epoch 27/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9742 - loss: 0.0338 - val_accuracy: 1.0000 - val_loss: 9.1007e-09
# Epoch 28/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9854 - loss: 0.0176 - val_accuracy: 1.0000 - val_loss: 9.6637e-09
# Epoch 29/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 1.0000 - val_loss: 1.0098e-08
# Epoch 30/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 221ms/step - accuracy: 0.9990 - loss: 0.0058 - val_accuracy: 1.0000 - val_loss: 1.0399e-08
# Epoch 31/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9990 - loss: 0.0076 - val_accuracy: 1.0000 - val_loss: 1.0190e-08
# Epoch 32/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9951 - loss: 0.0217 - val_accuracy: 1.0000 - val_loss: 1.0312e-08
# Epoch 33/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9884 - loss: 0.0239 - val_accuracy: 1.0000 - val_loss:
- loss: 0.0210 - val_accuracy: 1.0000 - val_loss: 6.6422e-09
# Epoch 104/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.9973 - loss: 0.0120 - val_accuracy: 1.0000 - val_loss: 5.6033e-09
# Epoch 105/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 1.0000 - val_loss: 5.0073e-09
# Epoch 106/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 1.0000 - val_loss: 4.8559e-09
# Epoch 107/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9951 - loss: 0.0288 - val_accuracy: 1.0000 - val_loss: 4.6218e-09
# Epoch 108/200
# ...
# Epoch 110/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9936 - loss: 0.0153 - val_accuracy: 1.0000 - val_loss: 3.3166e-12
# Epoch 111/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.9876 - loss: 0.0261 - val_accuracy: 1.0000 - val_loss: 3.6578e-12
# Epoch 112/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9923 - loss: 0.0161 - val_accuracy: 1.0000 - val_loss: 4.4945e-12
# Epoch 113/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9897 - loss: 0.0232 - val_accuracy: 1.0000 - val_loss: 6.7385e-12
# Epoch 114/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.9821 - loss: 0.0327 - val_accuracy: 1.0000 - val_loss: 7.3373e-12
# Epoch 115/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9974 - loss: 0.0133 - val_accuracy: 1.0000 - val_loss: 7.4418e-12
# Epoch 116/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9925 - loss: 0.0283 - val_accuracy: 1.0000 - val_loss: 8.6504e-12
# Epoch 117/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9961 - loss: 0.0099 - val_accuracy: 1.0000 - val_loss: 1.0172e-11
# Epoch 118/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.9940 - loss: 0.0155 - val_accuracy: 1.0000 - val_loss: 1.4216e-11
# Epoch 119/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9990 - loss: 0.0038 - val_accuracy: 1.0000 - val_loss: 2.0279e-11
# Epoch 120/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 1.0000 - val_loss: 2.7305e-11
# Epoch 121/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9979 - loss: 0.0052 - val_accuracy: 1.0000 - val_loss: 2.9181e-11
# Epoch 122/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9974 - loss: 0.0066 - val_accuracy: 1.0000 - val_loss: 3.3176e-11
# Epoch 123/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.9974 - loss: 0.0082 - val_accuracy: 1.0000 - val_loss: 3.4285e-11
# Epoch 124/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9961 - loss: 0.0072 - val_accuracy: 1.0000 - val_loss: 3.0057e-11
# Epoch 125/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9925 - loss: 0.0079 - val_accuracy: 1.0000 - val_loss: 2.4107e-11
# Epoch 126/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 0.9932 - loss: 0.0270 - val_accuracy: 1.0000 - val_loss: 2.3145e-11
# Epoch 127/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9935 - loss: 0.0095 - val_accuracy: 1.0000 - val_loss: 2.3608e-11
# Epoch 128/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9935 - loss: 0.0127 - val_accuracy: 1.0000 - val_loss: 2.5861e-11
# Epoch 129/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9944 - loss: 0.0125 - val_accuracy: 1.0000 - val_loss: 2.8115e-11
# Epoch 130/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9935 - loss: 0.0130 - val_accuracy: 1.0000 - val_loss: 2.6561e-11
# Epoch 131/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 0.9974 - loss: 0.0067 - val_accuracy: 1.0000 - val_loss: 2.4177e-11
# Epoch 132/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 0.9923 - loss: 0.0210 - val_accuracy: 1.0000 - val_loss: 1.9362e-11
# Epoch 133/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9858 - loss: 0.0205 - val_accuracy: 1.0000 - val_loss: 1.3329e-11
# Epoch 134/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 1.0351e-11
# Epoch 135/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.9957 - loss: 0.0163 - val_accuracy: 1.0000 - val_loss: 9.4038e-12
# Epoch 136/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 1.0000 - val_loss: 8.9166e-12
# Epoch 137/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 0.9979 - loss: 0.0201 - val_accuracy: 1.0000 - val_loss: 9.0606e-12
# Epoch 138/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9974 - loss: 0.0054 - val_accuracy: 1.0000 - val_loss: 9.2111e-12
# Epoch 139/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.9983 - loss: 0.0081 - val_accuracy: 1.0000 - val_loss: 8.9339e-12
# Epoch 140/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9884 - loss: 0.0638 - val_accuracy: 1.0000 - val_loss: 9.4436e-12
# Epoch 141/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9979 - loss: 0.0037 - val_accuracy: 1.0000 - val_loss: 1.0653e-11
# Epoch 142/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9983 - loss: 0.0094 - val_accuracy: 1.0000 - val_loss: 1.2599e-11
# Epoch 143/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 1.0000 - val_loss: 1.4250e-11
# Epoch 144/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9990 - loss: 0.0067 - val_accuracy: 1.0000 - val_loss: 1.5531e-11
# Epoch 145/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9901 - loss: 0.0133 - val_accuracy: 1.0000 - val_loss: 1.7411e-11
# Epoch 146/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 1.0000 - val_loss: 1.9490e-11
# Epoch 147/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9974 - loss: 0.0065 - val_accuracy: 1.0000 - val_loss: 1.9513e-11
# Epoch 148/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.9935 - loss: 0.0163 - val_accuracy: 1.0000 - val_loss: 2.1531e-11
# Epoch 149/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.9974 - loss: 0.0114 - val_accuracy: 1.0000 - val_loss: 2.3873e-11
# Epoch 150/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9880 - loss: 0.0253 - val_accuracy: 1.0000 - val_loss: 1.9752e-11
# Epoch 151/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9983 - loss: 0.0105 - val_accuracy: 1.0000 - val_loss: 1.5728e-11
# Epoch 152/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9845 - loss: 0.0224 - val_accuracy: 1.0000 - val_loss: 1.2265e-11
# Epoch 153/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9990 - loss: 0.0106 - val_accuracy: 1.0000 - val_loss: 9.7071e-12
# Epoch 154/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 1.0000 - val_loss: 8.7260e-12
# Epoch 155/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9944 - loss: 0.0120 - val_accuracy: 1.0000 - val_loss: 7.8859e-12
# Epoch 156/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9983 - loss: 0.0058 - val_accuracy: 1.0000 - val_loss: 7.4780e-12
# Epoch 157/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9983 - loss: 0.0032 - val_accuracy: 1.0000 - val_loss: 7.7128e-12
# Epoch 158/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 1.0000 - val_loss: 8.3678e-12
# Epoch 159/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 213ms/step - accuracy: 0.9938 - loss: 0.0590 - val_accuracy: 1.0000 - val_loss: 9.9075e-12
# Epoch 160/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9983 - loss: 0.0042 - val_accuracy: 1.0000 - val_loss: 1.1640e-11
# Epoch 161/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - accuracy: 0.9964 - loss: 0.0070 - val_accuracy: 1.0000 - val_loss: 1.3499e-11
# Epoch 162/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 1.0000 - val_loss: 1.3672e-11
# Epoch 163/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9961 - loss: 0.0055 - val_accuracy: 1.0000 - val_loss: 1.2639e-11
# Epoch 164/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 213ms/step - accuracy: 0.9925 - loss: 0.0148 - val_accuracy: 1.0000 - val_loss: 1.2407e-11
# Epoch 165/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9934 - loss: 0.0132 - val_accuracy: 1.0000 - val_loss: 1.2031e-11
# Epoch 166/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9850 - loss: 0.0209 - val_accuracy: 1.0000 - val_loss: 1.4083e-11
# Epoch 167/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9949 - loss: 0.0202 - val_accuracy: 1.0000 - val_loss: 1.5482e-11
# Epoch 168/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9961 - loss: 0.0136 - val_accuracy: 1.0000 - val_loss: 1.6707e-11
# Epoch 169/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 1.0000 - val_loss: 1.6419e-11
# Epoch 170/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.
- Accuracy: 100.0%
# ------------------------------------------------------------------------
# Average scores for all trial:
# > Accuracy: 100.0 (+- 0.0)
# > Loss: 6.199834565857542e-05
# ------------------------------------------------------------------------

# %% [markdown]
# #### Siamese Network with Triplet Loss for Classification

# %% [markdown]
# First we generate dataset for the triplet loss.
#
# Then we train a 2-layer GRU model to output a 128-dim encoding vector for each preprocessed video input.
#
# Finally, we store the average encoding vector for positive and negative classes for later use.
#
#
#
# ---
#
#
#
# Whenever there is a new video, we simply
#
# 1) get the preprocessed video as a vector
#
# 2) compare the distance(average_positive_encoding, video_encoding) vs. distance(average_negative_encoding, video_encoding) to assign a label 0 or 1.

# %%
# Data preprocessing
X_train = X_train.reshape(X_train.shape[0], 300, 4608)
print(X_train.shape, y_train.shape)
input_shape = X_train.shape[1:]
print(f"input_shape={input_shape}")

X_valid = X_valid.reshape(X_valid.shape[0], 300, 4608)
# Out:
# (259, 300, 4608) (259,)
# input_shape=(300, 4608)

# %%
import random

# Returns a list of randomly generated anchors, positives and negatives
# of size batch_size (default to 5000)
def create_batch(batch_size=5000):
    x_anchors = np.zeros((batch_size, 300, 4608))
    x_positives = np.zeros((batch_size, 300, 4608))
    x_negatives = np.zeros((batch_size, 300, 4608))

    for i in range(0, batch_size):
        # We need to find an anchor, a positive example and a negative example
        random_index = random.randint(0, X_train.shape[0] - 1)
        x_anchor = X_train[random_index]
        y = y_train[random_index]

        indices_for_pos = np.squeeze(np.where(y_train == y))
        indices_for_neg = np.squeeze(np.where(y_train != y))

        x_positive = X_train[indices_for_pos[random.randint(0, len(indices_for_pos) - 1)]]
        x_negative = X_train[indices_for_neg[random.randint(0, len(indices_for_neg) - 1)]]

        x_anchors[i] = x_anchor
        x_positives[i] = x_positive
        x_negatives[i] = x_negative

    return [x_anchors, x_positives, x_negatives]

# %%
emb_size = 64

def create_embedding_model(input_shape):
  X_input = Input(shape=input_shape)
  X = Conv1D(filters=196, kernel_size=15, strides=4)(X_input) #filters = 196, kernel_size = 15
  # X = MaxPooling1D(pool_size=15)(X)
  X = MaxPooling1D(pool_size=30, strides=15, padding='valid')(X) # pool 30, strides 15 is fine!
  X = BatchNormalization()(X)
  X = Activation("relu")(X)
  X = Dropout(rate=0.8)(X)

  X = GRU(units=128, return_sequences=True)(X)
  X = Dropout(rate=0.8)(X)
  X = BatchNormalization()(X)

  X = GRU(units=128, return_sequences=True)(X)
  X = Dropout(rate=0.8)(X)
  X = BatchNormalization()(X)

  X = Dropout(rate=0.5)(X) #0.8 is fine!

  X = Flatten()(X)
  X = Dense(emb_size, activation="sigmoid")(X)

  model = Model(inputs=X_input, outputs=X)

  return model

embedding_model=create_embedding_model(input_shape=(Tx, dims))
embedding_model.summary()
# Out:
# Model: "functional_35"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 300, 4608)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d (Conv1D)                      │ (None, 72, 196)             │      13,547,716 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d (MaxPooling1D)         │ (None, 3, 196)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 3, 196)              │             784 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 3, 196)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 3, 196)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru (GRU)                            │ (None, 3, 128)              │         125,184 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 3, 128)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 3, 128)              │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_1 (GRU)                          │ (None, 3, 128)              │          99,072 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 3, 128)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 3, 128)              │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 3, 128)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 384)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │          24,640 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 13,798,420 (52.64 MB)
#  Trainable params: 13,797,516 (52.63 MB)
#  Non-trainable params: 904 (3.53 KB)

# %%
# Siamese Network

input_anchor = Input(shape=(Tx, dims,))
input_positive = Input(shape=(Tx, dims,))
input_negative = Input(shape=(Tx, dims,))

embedding_anchor = embedding_model(input_anchor)
embedding_positive = embedding_model(input_positive)
embedding_negative = embedding_model(input_negative)

output = tf.keras.layers.concatenate([embedding_anchor, embedding_positive, embedding_negative], axis=1)

net = tf.keras.models.Model([input_anchor, input_positive, input_negative], output)
net.summary()
# Out:
# Model: "functional_36"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1             │ (None, 300, 4608)      │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_2             │ (None, 300, 4608)      │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_3             │ (None, 300, 4608)      │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ functional_35             │ (None, 64)             │     13,798,420 │ input_layer_1[0][0],   │
# │ (Functional)              │                        │                │ input_layer_2[0][0],   │
# │                           │                        │                │ input_layer_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 192)            │              0 │ functional_35[0][0],   │
# │                           │                        │                │ functional_35[1][0],   │
# │                           │                        │                │ functional_35[2][0]    │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 13,798,420 (52.64 MB)
#  Trainable params: 13,797,516 (52.63 MB)
#  Non-trainable params: 904 (3.53 KB)

# %%
import tensorflow as tf
import numpy as np
from sklearn.decomposition import PCA

# we will use this function to visualize how the embedding model is doing over time.
class PCAPlotter(tf.keras.callbacks.Callback):

    def __init__(self, plt, embedding_model, x_test, y_test):
        super(PCAPlotter, self).__init__()
        self.embedding_model = embedding_model
        self.x_test = x_test
        self.y_test = y_test
        self.fig = plt.figure(figsize=(9, 4))
        self.ax1 = plt.subplot(1, 2, 1)
        self.ax2 = plt.subplot(1, 2, 2)
        plt.ion()

        self.losses = []

    def plot(self, epoch=None, plot_loss=False):
        x_test_embeddings = self.embedding_model.predict(self.x_test)
        pca_out = PCA(n_components=2).fit_transform(x_test_embeddings)
        self.ax1.clear()
        self.ax1.scatter(pca_out[:, 0], pca_out[:, 1], c=self.y_test, cmap='seismic')
        if plot_loss:
            self.ax2.clear()
            self.ax2.plot(range(epoch), self.losses)
            self.ax2.set_xlabel('Epochs')
            self.ax2.set_ylabel('Loss')
        self.fig.canvas.draw()

    def on_train_begin(self, logs=None):
        self.losses = []
        self.fig.show()
        self.fig.canvas.draw()
        self.plot()

    def on_epoch_end(self, epoch, logs=None):
        self.losses.append(logs.get('loss'))
        self.plot(epoch+1, plot_loss=True)

# %%
# Triplet Loss

alpha = 0.2 # 0.6 was fine

def triplet_loss(y_true, y_pred):
    anchor, positive, negative = y_pred[:,:emb_size], y_pred[:,emb_size:2*emb_size], y_pred[:,2*emb_size:]
    positive_dist = tf.reduce_mean(tf.square(anchor - positive), axis=1)
    negative_dist = tf.reduce_mean(tf.square(anchor - negative), axis=1)
    return tf.maximum(positive_dist - negative_dist + alpha, 0.)

# Data Generator

def data_generator(batch_size=64):
    while True:
        x = create_batch(batch_size)
        y = np.zeros((batch_size, 3*emb_size))
        yield tuple(x), y

# Model Training
batch_size = m
epochs = 100 #int(400000/m/100)
steps_per_epoch = int(m/batch_size)

net.compile(loss=triplet_loss, optimizer=Adam(learning_rate=3e-4, beta_1=0.9, beta_2=0.999, decay=0.01, epsilon=1e-7))


# early stopping
early_stopping_callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10, restore_best_weights=True)


_ = net.fit(
    data_generator(batch_size),
    steps_per_epoch=steps_per_epoch,
    epochs=epochs, verbose=True,
    callbacks=[
        early_stopping_callback,
        PCAPlotter(
            plt, embedding_model,
            X_valid[:1000], y_valid[:1000]
        )]
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/optimizers/base_optimizer.py:86: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 23s 23s/step - loss: 0.2006
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.1998
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step - loss: 0.2000
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step - loss: 0.1954
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step - loss: 0.2002
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step - loss: 0.1972
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step - loss: 0.1993
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step - loss: 0.2001
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step - loss: 0.1978
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step - loss: 0.2030
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step - loss: 0.2015
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step - loss: 0.2006
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step - loss: 0.2028
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step - loss: 0.1982

# %%
# we need to store the average truth vector
# and the average lie vector learned
# with training set for verify
X_train_emb = embedding_model.predict(X_train)

truth_emb = []
lie_emb = []
for xi, yi in zip(X_train_emb, y_train):
  if yi == 1:
    truth_emb.append(xi)
  else:
    lie_emb.append(xi)
print(f"There are {len(truth_emb)} truths and {len(lie_emb)} lies.")

average_truth_emb = np.mean(truth_emb, axis=0)
average_lie_emb = np.mean(lie_emb, axis=0)

database={}
database['truth'] = average_truth_emb
database['lie'] = average_lie_emb
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step
# There are 129 truths and 130 lies.

# %% [markdown]
# Next we will validate results

# %%
# Validation Accuracy
X_valid_emb = embedding_model.predict(X_valid)
print(f"X_valid.shape={X_valid.shape}, X_valid_emb.shape={X_valid_emb.shape}, y_valid.shape={y_valid.shape}")

# verify function: given an embedding, will tell whether or not it is truth
# based on distance from the average truth and the average lie vectors.
def verify(emb, embedding_model, database):
  dist_truth = np.linalg.norm(emb - database["truth"])
  dist_lie = np.linalg.norm(emb - database["lie"])
  print(f"dist_truth={dist_truth}, dist_lie={dist_lie}")
  return 1 if dist_truth < dist_lie  else 0


# now we measure the accuracy on validation set.
count = 0
y_pred = []

for emb, y in zip(X_valid_emb, y_valid):
  y_predict = verify(emb, embedding_model, database)
  y_pred.append(y_predict)
  if y_predict == y:
    count += 1
  else:
    print("y_predict: ", y_predict, "y: ", y)


accuracy = count/X_valid_emb.shape[0]
acc_str = '%.2f' % (accuracy*100)
print('Validation Accuracy: '+acc_str+'%')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# X_valid.shape=(29, 300, 4608), X_valid_emb.shape=(29, 64), y_valid.shape=(29,)
# dist_truth=0.18820466101169586, dist_lie=0.1847376674413681
# y_predict:  0 y:  1
# dist_truth=0.2433662861585617, dist_lie=0.25899556279182434
# y_predict:  1 y:  0
# dist_truth=0.30025020241737366, dist_lie=0.2882433533668518
# dist_truth=0.26663854718208313, dist_lie=0.2599743604660034
# dist_truth=0.30703282356262207, dist_lie=0.29885268211364746
# dist_truth=0.3966037631034851, dist_lie=0.3918764889240265
# dist_truth=0.4686795473098755, dist_lie=0.453168660402298
# y_predict:  0 y:  1
# dist_truth=0.32949554920196533, dist_lie=0.32095637917518616
# dist_truth=0.22481048107147217, dist_lie=0.20630186796188354
# y_predict:  0 y:  1
# dist_truth=0.26703763008117676, dist_lie=0.26288333535194397
# dist_truth=0.43872395157814026, dist_lie=0.45308709144592285
# y_predict:  1 y:  0
# dist_truth=0.217582106590271, dist_lie=0.21586227416992188
# dist_truth=0.4012228548526764, dist_lie=0.3954797089099884
# dist_truth=0.3072848916053772, dist_lie=0.3180750012397766
# y_predict:  1 y:  0
# dist_truth=0.2041119635105133, dist_lie=0.20055201649665833
# y_predict:  0 y:  1
# dist_truth=0.16563144326210022, dist_lie=0.16332899034023285
# y_predict:  0 y:  1
# dist_truth=0.24680301547050476, dist_lie=0.24767400324344635
# dist_truth=0.2673991918563843, dist_lie=0.26684749126434326
# y_predict:  0 y:  1
# dist_truth=0.30508360266685486, dist_lie=0.314577579498291
# y_predict:  1 y:  0
# dist_truth=0.27598318457603455, dist_lie=0.27134743332862854
# y_predict:  0 y:  1
# dist_truth=0.26104736328125, dist_lie=0.2568988502025604
# dist_truth=0.22759869694709778, dist_lie=0.22984708845615387
# dist_truth=0.31086504459381104, dist_lie=0.3093700408935547
# dist_truth=0.2637920081615448, dist_lie=0.2543318271636963
# dist_truth=0.27713772654533386, dist_lie=0.2904013395309448
# dist_truth=0.3245707154273987, dist_lie=0.32471856474876404
# y_predict:  1 y:  0
# dist_truth=0.30716472864151, dist_lie=0.3205995261669159
# dist_truth=0.35129886865615845, dist_lie=0.33907273411750793
# y_predict:  0 y:  1
# dist_truth=0.207301065325737, dist_lie=0.21482792496681213
# Validation Accuracy: 55.17%

# %%
# Train accuracy
X_train_emb = embedding_model.predict(X_train)
print(f"X_train.shape={X_train.shape}, X_train_emb.shape={X_train_emb.shape}, y_train.shape={y_train.shape}")

# verify function: given an embedding, will tell whether or not it is truth
# based on distance from the average truth and the average lie vectors.
def verify(emb, embedding_model, database):
  dist_truth = np.linalg.norm(emb - database["truth"])
  dist_lie = np.linalg.norm(emb - database["lie"])
  print(f"dist_truth={dist_truth}, dist_lie={dist_lie}")
  return 1 if dist_truth < dist_lie  else 0


# now we measure the accuracy on validation set.
count = 0

y_pred = []
for emb, y in zip(X_train_emb, y_train):
  y_predict = verify(emb, embedding_model, database)
  y_pred.append(y_predict)
  # print("y_predict: ", y_predict, "y: ", y)
  if y_predict == y:
    count += 1
  else:
    print("y_predict: ", y_predict, "y: ", y)

accuracy = count/X_train_emb.shape[0]
acc_str = '%.2f' % (accuracy*100)
print('Train Accuracy: '+acc_str+'%')
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# X_train.shape=(259, 300, 4608), X_train_emb.shape=(259, 64), y_train.shape=(259,)
# dist_truth=0.2715870440006256, dist_lie=0.28095757961273193
# dist_truth=0.27623313665390015, dist_lie=0.2875820994377136
# y_predict:  1 y:  0
# dist_truth=0.28447896242141724, dist_lie=0.2811916470527649
# dist_truth=0.33928096294403076, dist_lie=0.3486465513706207
# dist_truth=0.378391295671463, dist_lie=0.37742945551872253
# dist_truth=0.3213973045349121, dist_lie=0.32011961936950684
# dist_truth=0.3315046727657318, dist_lie=0.33970439434051514
# dist_truth=0.33691084384918213, dist_lie=0.33112338185310364
# y_predict:  0 y:  1
# dist_truth=0.4461281895637512, dist_lie=0.4362105131149292
# dist_truth=0.36963215470314026, dist_lie=0.3636176586151123
# y_predict:  0 y:  1
# dist_truth=0.32885095477104187, dist_lie=0.3140828311443329
# dist_truth=0.35042575001716614, dist_lie=0.3559064567089081
# y_predict:  1 y:  0
# dist_truth=0.4445159435272217, dist_lie=0.43365782499313354
# y_predict:  0 y:  1
# dist_truth=0.23032161593437195, dist_lie=0.24289895594120026
# y_predict:  1 y:  0
# dist_truth=0.30546483397483826, dist_lie=0.2997255027294159
# dist_truth=0.35038506984710693, dist_lie=0.35395529866218567
# dist_truth=0.3374720513820648, dist_lie=0.33549603819847107
# dist_truth=0.26058927178382874, dist_lie=0.25668400526046753
# dist_truth=0.36989280581474304, dist_lie=0.38922685384750366
# dist_truth=0.27361539006233215, dist_lie=0.28537559509277344
# y_predict:  1 y:  0
# dist_truth=0.40409255027770996, dist_lie=0.3932161331176758
# dist_truth=0.26363101601600647, dist_lie=0.2703395187854767
# dist_truth=0.3044075667858124, dist_lie=0.30869925022125244
# y_predict:  1 y:  0
# dist_truth=0.32588812708854675, dist_lie=0.3178060054779053
# dist_truth=0.46657824516296387, dist_lie=0.46559789776802063
# dist_truth=0.3964464068412781, dist_lie=0.4061562120914459
# dist_truth=0.24559994041919708, dist_lie=0.263214111328125
# dist_truth=0.3302510678768158, dist_lie=0.332258403301239
# dist_truth=0.3167422115802765, dist_lie=0.3007064461708069
# y_predict:  0 y:  1
# dist_truth=0.261577308177948, dist_lie=0.2516670525074005
# dist_truth=0.31289470195770264, dist_lie=0.30376768112182617
# y_predict:  0 y:  1
# dist_truth=0.38924744725227356, dist_lie=0.39994609355926514
# dist_truth=0.31319087743759155, dist_lie=0.3212108612060547
# y_predict:  1 y:  0
# dist_truth=0.33206167817115784, dist_lie=0.3196633756160736
# dist_truth=0.3536902666091919, dist_lie=0.36968740820884705
# dist_truth=0.4087064564228058, dist_lie=0.4057314097881317
# dist_truth=0.331402450799942, dist_lie=0.3414648473262787
# y_predict:  1 y:  0
# dist_truth=0.2560720443725586, dist_lie=0.249437615275383
# y_predict:  0 y:  1
# dist_truth=0.4488319456577301, dist_lie=0.44848957657814026
# y_predict:  0 y:  1
# dist_truth=0.28982144594192505, dist_lie=0.2785743772983551
# y_predict:  0 y:  1
# dist_truth=0.3002798855304718, dist_lie=0.30161193013191223
# y_predict:  1 y:  0
# dist_truth=0.34657034277915955, dist_lie=0.34958550333976746
# dist_truth=0.43659907579421997, dist_lie=0.4284217655658722
# dist_truth=0.3321923613548279, dist_lie=0.3253698945045471
# dist_truth=0.1960647851228714, dist_lie=0.18666096031665802
# dist_truth=0.30202338099479675, dist_lie=0.2962862253189087
# y_predict:  0 y:  1
# dist_truth=0.3231975734233856, dist_lie=0.3098476827144623
# y_predict:  0 y:  1
# dist_truth=0.2699306309223175, dist_lie=0.2714928686618805
# dist_truth=0.31258201599121094, dist_lie=0.30651500821113586
# dist_truth=0.3347068727016449, dist_lie=0.32934534549713135
# dist_truth=0.30208253860473633, dist_lie=0.3011426627635956
# y_predict:  0 y:  1
# dist_truth=0.4066637456417084, dist_lie=0.39381134510040283
# dist_truth=0.40107855200767517, dist_lie=0.38863304257392883
# dist_truth=0.30499130487442017, dist_lie=0.3012392818927765
# dist_truth=0.3557523190975189, dist_lie=0.34858205914497375
# y_predict:  0 y:  1
# dist_truth=0.36400872468948364, dist_lie=0.3646870255470276
# dist_truth=0.30304858088493347, dist_lie=0.30129268765449524
# y_predict:  0 y:  1
# dist_truth=0.32228943705558777, dist_lie=0.3150187134742737
# dist_truth=0.30883365869522095, dist_lie=0.3034445345401764
# dist_truth=0.3058341443538666, dist_lie=0.2972119450569153
# dist_truth=0.2796831429004669, dist_lie=0.277445524930954
# dist_truth=0.26703688502311707, dist_lie=0.2754093408584595
# dist_truth=0.2852429449558258, dist_lie=0.2935076951980591
# y_predict:  1 y:  0
# dist_truth=0.30176907777786255, dist_lie=0.29238852858543396
# y_predict:  0 y:  1
# dist_truth=0.257698655128479, dist_lie=0.2529747188091278
# dist_truth=0.2672872245311737, dist_lie=0.27359631657600403
# y_predict:  1 y:  0
# dist_truth=0.2907610535621643, dist_lie=0.2929925322532654
# y_predict:  1 y:  0
# dist_truth=0.41558682918548584, dist_lie=0.40964818000793457
# y_predict:  0 y:  1
# dist_truth=0.2970791757106781, dist_lie=0.2917332351207733
# dist_truth=0.30226248502731323, dist_lie=0.30588293075561523
# dist_truth=0.30551227927207947, dist_lie=0.2947215735912323
# dist_truth=0.3842592239379883, dist_lie=0.38093170523643494
# dist_truth=0.41797876358032227, dist_lie=0.40738359093666077
# y_predict:  0 y:  1
# dist_truth=0.3449116349220276, dist_lie=0.3436216711997986
# y_predict:  0 y:  1
# dist_truth=0.27330639958381653, dist_lie=0.2760274410247803
# dist_truth=0.5182258486747742, dist_lie=0.5139405131340027
# y_predict:  0 y:  1
# dist_truth=0.3207716643810272, dist_lie=0.33838796615600586
# dist_truth=0.36529409885406494, dist_lie=0.38158559799194336
# y_predict:  1 y:  0
# dist_truth=0.2550540268421173, dist_lie=0.24785009026527405
# dist_truth=0.262703537940979, dist_lie=0.2522623836994171
# dist_truth=0.3741515576839447, dist_lie=0.3815399408340454
# y_predict:  1 y:  0
# dist_truth=0.315822571516037, dist_lie=0.3185316324234009
# y_predict:  1 y:  0
# dist_truth=0.33542412519454956, dist_lie=0.3290990889072418
# y_predict:  0 y:  1
# dist_truth=0.22988560795783997, dist_lie=0.2256442755460739
# y_predict:  0 y:  1
# dist_truth=0.38362979888916016, dist_lie=0.3794872462749481
# dist_truth=0.32514750957489014, dist_lie=0.3256275951862335
# y_predict:  1 y:  0
# dist_truth=0.23282857239246368, dist_lie=0.24120588600635529
# y_predict:  1 y:  0
# dist_truth=0.290282666683197, dist_lie=0.28534600138664246
# y_predict:  0 y:  1
# dist_truth=0.3085912764072418, dist_lie=0.31991511583328247
# y_predict:  1 y:  0
# dist_truth=0.2990962266921997, dist_lie=0.307594358921051
# y_predict:  1 y:  0
# dist_truth=0.42117220163345337, dist_lie=0.4110155701637268
# dist_truth=0.2980331480503082, dist_lie=0.2838536500930786
# y_predict:  0 y:  1
# dist_truth=0.24564675986766815, dist_lie=0.2494872361421585
# dist_truth=0.24909242987632751, dist_lie=0.25743770599365234
# dist_truth=0.3196813762187958, dist_lie=0.3127923309803009
# dist_truth=0.24238766729831696, dist_lie=0.24672310054302216
# dist_truth=0.38757744431495667, dist_lie=0.3974655866622925
# dist_truth=0.25511685013771057, dist_lie=0.26738500595092773
# dist_truth=0.3092515766620636, dist_lie=0.29933395981788635
# y_predict:  0 y:  1
# dist_truth=0.24916408956050873, dist_lie=0.2538757920265198
# y_predict:  1 y:  0
# dist_truth=0.3014738857746124, dist_lie=0.2924436628818512
# y_predict:  0 y:  1
# dist_truth=0.2352667897939682, dist_lie=0.22777704894542694
# y_predict:  0 y:  1
# dist_truth=0.29301917552948, dist_lie=0.2856541574001312
# y_predict:  0 y:  1
# dist_truth=0.2854149639606476, dist_lie=0.28681251406669617
# y_predict:  1 y:  0
# dist_truth=0.31282418966293335, dist_lie=0.3252785801887512
# dist_truth=0.20621852576732635, dist_lie=0.20298142731189728
# dist_truth=0.33515027165412903, dist_lie=0.330787718296051
# dist_truth=0.28375083208084106, dist_lie=0.2744002044200897
# dist_truth=0.29557615518569946, dist_lie=0.28475406765937805
# dist_truth=0.38763517141342163, dist_lie=0.3946084678173065
# dist_truth=0.22657881677150726, dist_lie=0.2202792912721634
# y_predict:  0 y:  1
# dist_truth=0.24564440548419952, dist_lie=0.2462870329618454
# y_predict:  1 y:  0
# dist_truth=0.46270254254341125, dist_lie=0.45241135358810425
# y_predict:  0 y:  1
# dist_truth=0.3499915599822998, dist_lie=0.3497847020626068
# dist_truth=0.30873510241508484, dist_lie=0.31606000661849976
# dist_truth=0.39902791380882263, dist_lie=0.39793816208839417
# dist_truth=0.3429777920246124, dist_lie=0.33870333433151245
# y_predict:  0 y:  1
# dist_truth=0.3496721386909485, dist_lie=0.36568155884742737
# dist_truth=0.3909682333469391, dist_lie=0.40711265802383423
# y_predict:  1 y:  0
# dist_truth=0.3242628276348114, dist_lie=0.3276713788509369
# dist_truth=0.3626573979854584, dist_lie=0.35526803135871887
# y_predict:  0 y:  1
# dist_truth=0.30936703085899353, dist_lie=0.3179999589920044
# dist_truth=0.33442655205726624, dist_lie=0.3343980312347412
# y_predict:  0 y:  1
# dist_truth=0.3273564279079437, dist_lie=0.34397804737091064
# dist_truth=0.311208039522171, dist_lie=0.30105218291282654
# dist_truth=0.3171253204345703, dist_lie=0.30361735820770264
# y_predict:  0 y:  1
# dist_truth=0.3573755919933319, dist_lie=0.3528725802898407
# y_predict:  0 y:  1
# dist_truth=0.36746954917907715, dist_lie=0.3686537742614746
# dist_truth=0.3541683852672577, dist_lie=0.3544975519180298
# y_predict:  1 y:  0
# dist_truth=0.37023693323135376, dist_lie=0.3680773675441742
# y_predict:  0 y:  1
# dist_truth=0.486349493265152, dist_lie=0.48241910338401794
# y_predict:  0 y:  1
# dist_truth=0.3319646716117859, dist_lie=0.3488542437553406
# y_predict:  1 y:  0
# dist_truth=0.3935665190219879, dist_lie=0.3901766538619995
# y_predict:  0 y:  1
# dist_truth=0.35544079542160034, dist_lie=0.3718312680721283
# dist_truth=0.2347034215927124, dist_lie=0.23336036503314972
# y_predict:  0 y:  1
# dist_truth=0.20559161901474, dist_lie=0.20073002576828003
# y_predict:  0 y:  1
# dist_truth=0.3145471215248108, dist_lie=0.3061930239200592
# y_predict:  0 y:  1
# dist_truth=0.28095823526382446, dist_lie=0.2711200416088104
# y_predict:  0 y:  1
# dist_truth=0.2791871428489685, dist_lie=0.2820918560028076
# y_predict:  1 y:  0
# dist_truth=0.2726060748100281, dist_lie=0.2712400257587433
# dist_truth=0.3470958173274994, dist_lie=0.3480001389980316
# y_predict:  1 y:  0
# dist_truth=0.37963151931762695, dist_lie=0.37659236788749695
# y_predict:  0 y:  1
# dist_truth=0.20409168303012848, dist_lie=0.21793116629123688
# dist_truth=0.40310120582580566, dist_lie=0.3984825909137726
# y_predict:  0 y:  1
# dist_truth=0.3673645853996277, dist_lie=0.370364785194397
# dist_truth=0.27806299924850464, dist_lie=0.28565141558647156
# y_predict:  1 y:  0
# dist_truth=0.22803963720798492, dist_lie=0.22086574137210846
# y_predict:  0 y:  1
# dist_truth=0.310847669839859, dist_lie=0.3058421015739441
# dist_truth=0.27874693274497986, dist_lie=0.2679089903831482
# dist_truth=0.21692095696926117, dist_lie=0.21150727570056915
# dist_truth=0.3228737413883209, dist_lie=0.32361963391304016
# dist_truth=0.4371958076953888, dist_lie=0.4361376464366913
# dist_truth=0.2933468222618103, dist_lie=0.2869437634944916
# dist_truth=0.29266345500946045, dist_lie=0.29586780071258545
# y_predict:  1 y:  0
# dist_truth=0.30180636048316956, dist_lie=0.30214938521385193
# y_predict:  1 y:  0
# dist_truth=0.35129106044769287, dist_lie=0.3461253046989441
# dist_truth=0.29830390214920044, dist_lie=0.28974661231040955
# dist_truth=0.4608907401561737, dist_lie=0.4610319435596466
# dist_truth=0.3101719319820404, dist_lie=0.3090319335460663
# y_predict:  0 y:  1
# dist_truth=0.32506969571113586, dist_lie=0.32868048548698425
# dist_truth=0.30479317903518677, dist_lie=0.29593873023986816
# dist_truth=0.3140052855014801, dist_lie=0.3187974691390991
# y_predict:  1 y:  0
# dist_truth=0.3158428966999054, dist_lie=0.3317652940750122
# dist_truth=0.3148117661476135, dist_lie=0.32804691791534424
# y_predict:  1 y:  0
# dist_truth=0.31056955456733704, dist_lie=0.30837419629096985
# y_predict:  0 y:  1
# dist_truth=0.40175703167915344, dist_lie=0.39600837230682373
# y_predict:  0 y:  1
# dist_truth=0.43175217509269714, dist_lie=0.41770362854003906
# dist_truth=0.33922767639160156, dist_lie=0.34258386492729187
# dist_truth=0.3078446388244629, dist_lie=0.3085135817527771
# y_predict:  1 y:  0
# dist_truth=0.3335689306259155, dist_lie=0.3303277790546417
# y_predict:  0 y:  1
# dist_truth=0.230823814868927, dist_lie=0.23063308000564575
# dist_truth=0.352165549993515, dist_lie=0.3468284010887146
# dist_truth=0.3269164562225342, dist_lie=0.34006547927856445
# y_predict:  1 y:  0
# dist_truth=0.3241599202156067, dist_lie=0.334876149892807
# dist_truth=0.28785479068756104, dist_lie=0.29939472675323486
# dist_truth=0.2934243679046631, dist_lie=0.2830432057380676
# dist_truth=0.29277852177619934, dist_lie=0.2949509024620056
# dist_truth=0.35866278409957886, dist_lie=0.3731441795825958
# dist_truth=0.430292010307312, dist_lie=0.4411744475364685
# dist_truth=0.3203483521938324, dist_lie=0.31196510791778564
# dist_truth=0.3531590700149536, dist_lie=0.34392237663269043
# dist_truth=0.32536202669143677, dist_lie=0.3267366290092468
# y_predict:  1 y:  0
# dist_truth=0.30414900183677673, dist_lie=0.3077620267868042
# dist_truth=0.24563288688659668, dist_lie=0.2419731169939041
# y_predict:  0 y:  1
# dist_truth=0.3444399833679199, dist_lie=0.33046481013298035
# dist_truth=0.2660887837409973, dist_lie=0.24913418292999268
# dist_truth=0.35818588733673096, dist_lie=0.3710857033729553
# dist_truth=0.34673139452934265, dist_lie=0.3378179371356964
# dist_truth=0.29767829179763794, dist_lie=0.29159870743751526
# dist_truth=0.27312326431274414, dist_lie=0.26681193709373474
# dist_truth=0.3025650084018707, dist_lie=0.29983144998550415
# y_predict:  0 y:  1
# dist_truth=0.42769309878349304, dist_lie=0.419217973947525
# dist_truth=0.4281010627746582, dist_lie=0.44216400384902954
# y_predict:  1 y:  0
# dist_truth=0.31939467787742615, dist_lie=0.3133479356765747
# y_predict:  0 y:  1
# dist_truth=0.2675359845161438, dist_lie=0.26118627190589905
# y_predict:  0 y:  1
# dist_truth=0.27766281366348267, dist_lie=0.2653357982635498
# dist_truth=0.284309983253479, dist_lie=0.2926581799983978
# dist_truth=0.2622459828853607, dist_lie=0.259047269821167
# y_predict:  0 y:  1
# dist_truth=0.3106759488582611, dist_lie=0.31742948293685913
# y_predict:  1 y:  0
# dist_truth=0.28511252999305725, dist_lie=0.29621368646621704
# dist_truth=0.285005122423172, dist_lie=0.27466556429862976
# y_predict:  0 y:  1
# dist_truth=0.34603726863861084, dist_lie=0.34624138474464417
# y_predict:  1 y:  0
# dist_truth=0.3667525351047516, dist_lie=0.3692016005516052
# y_predict:  1 y:  0
# dist_truth=0.28397950530052185, dist_lie=0.28832367062568665
# dist_truth=0.3728216290473938, dist_lie=0.3566473126411438
# dist_truth=0.25456830859184265, dist_lie=0.2541723847389221
# dist_truth=0.3892657458782196, dist_lie=0.38063082098960876
# dist_truth=0.46610066294670105, dist_lie=0.4508414566516876
# y_predict:  0 y:  1
# dist_truth=0.2927873432636261, dist_lie=0.2998228669166565
# dist_truth=0.38326019048690796, dist_lie=0.3966889977455139
# dist_truth=0.3919149339199066, dist_lie=0.3873683214187622
# dist_truth=0.33920755982398987, dist_lie=0.35500049591064453
# dist_truth=0.3945452570915222, dist_lie=0.3934490978717804
# dist_truth=0.42014190554618835, dist_lie=0.4397365152835846
# dist_truth=0.2784462869167328, dist_lie=0.2891887128353119
# y_predict:  1 y:  0
# dist_truth=0.29431402683258057, dist_lie=0.28360715508461
# y_predict:  0 y:  1
# dist_truth=0.34036436676979065, dist_lie=0.3382713496685028
# dist_truth=0.2878299951553345, dist_lie=0.2827181816101074
# y_predict:  0 y:  1
# dist_truth=0.3433612883090973, dist_lie=0.3571239411830902
# dist_truth=0.2855418026447296, dist_lie=0.29488253593444824
# y_predict:  1 y:  0
# dist_truth=0.31112250685691833, dist_lie=0.3101503551006317
# y_predict:  0 y:  1
# dist_truth=0.3930761516094208, dist_lie=0.4015088975429535
# y_predict:  1 y:  0
# dist_truth=0.3862632215023041, dist_lie=0.404481440782547
# dist_truth=0.3247532546520233, dist_lie=0.3378022015094757
# y_predict:  1 y:  0
# dist_truth=0.2618330717086792, dist_lie=0.26649704575538635
# y_predict:  1 y:  0
# dist_truth=0.3449539244174957, dist_lie=0.3402908742427826
# dist_truth=0.32366207242012024, dist_lie=0.3258623480796814
# dist_truth=0.2993037700653076, dist_lie=0.3049641251564026
# dist_truth=0.31836172938346863, dist_lie=0.3290864825248718
# y_predict:  1 y:  0
# dist_truth=0.2311912626028061, dist_lie=0.22582906484603882
# dist_truth=0.3080441653728485, dist_lie=0.317445307970047
# y_predict:  1 y:  0
# dist_truth=0.2515351474285126, dist_lie=0.24913457036018372
# y_predict:  0 y:  1
# dist_truth=0.30469417572021484, dist_lie=0.30815589427948
# dist_truth=0.32037100195884705, dist_lie=0.33977362513542175
# y_predict:  1 y:  0
# dist_truth=0.22001339495182037, dist_lie=0.22868266701698303
# dist_truth=0.33949244022369385, dist_lie=0.33849793672561646
# dist_truth=0.300972044467926, dist_lie=0.3045266568660736
# y_predict:  1 y:  0
# dist_truth=0.2711229622364044, dist_lie=0.28546521067619324
# y_predict:  1 y:  0
# dist_truth=0.25439202785491943, dist_lie=0.2655158042907715
# dist_truth=0.3574128746986389, dist_lie=0.3564256727695465
# y_predict:  0 y:  1
# dist_truth=0.2884829640388489, dist_lie=0.27990683913230896
# dist_truth=0.3821916878223419, dist_lie=0.36803266406059265
# y_predict:  0 y:  1
# dist_truth=0.2427726686000824, dist_lie=0.24316103756427765
# dist_truth=0.430743932723999, dist_lie=0.44599083065986633
# dist_truth=0.38228508830070496, dist_lie=0.38704878091812134
# dist_truth=0.2803718149662018, dist_lie=0.2723933160305023
# dist_truth=0.435017466545105, dist_lie=0.44218623638153076
# y_predict:  1 y:  0
# dist_truth=0.25888246297836304, dist_lie=0.2675541639328003
# dist_truth=0.32020407915115356, dist_lie=0.3127281069755554
# y_predict:  0 y:  1
# dist_truth=0.2741756737232208, dist_lie=0.28368785977363586
# y_predict:  1 y:  0
# dist_truth=0.26531898975372314, dist_lie=0.2557404935359955
# dist_truth=0.33063971996307373, dist_lie=0.3393383026123047
# y_predict:  1 y:  0
# dist_truth=0.29814067482948303, dist_lie=0.2811073362827301
# dist_truth=0.31363651156425476, dist_lie=0.3114301860332489
# y_predict:  0 y:  1
# dist_truth=0.3795117437839508, dist_lie=0.38004031777381897
# dist_truth=0.3552730083465576, dist_lie=0.34456342458724976
# dist_truth=0.36608126759529114, dist_lie=0.3576258420944214
# y_predict:  0 y:  1
# dist_truth=0.314220130443573, dist_lie=0.3033534586429596
# dist_truth=0.41500088572502136, dist_lie=0.4194307327270508
# Train Accuracy: 55.98%

# %%
plot_confusion_matrix(np.array(y_train), np.array(y_pred), title='Confusion Matrix')
# Out:
# [[79 51]
#  [63 66]]

# %%
# Predict using the model
y_pred = gru_model.predict(X_valid)

# You can then use y_pred for further analysis or evaluation
# For example, you can convert probabilities to class labels if needed
y_pred_labels = np.argmax(y_pred, axis=1)

y_pred_labels
